# %%
from C4I import benchmarks, clustering, evaluation, investment, risk_factors_nnpca_super_daily_only, utils
import pandas as pd
import numpy as np
import pickle

# %% [markdown]
# Source

# %%
def An_Unsupervised_Learning_Framework(X, n_pcs, len_fold, n_win,temp_path=None,
                                scaler_pre='MinMax', coll_threshold=0.5, SEED=1,
                                lasso_fold=5, min_rfs=2, max_rfs=4, n_round=3,
                                scaler='Standard',
                                opt_hyper_port={'maxiter':200, 'disp':True},
                                port_select=3, verbose=True):
    '''
    INPUT:
        X: DataFrame, contains assets daily prices
        n_pcs: number of Principal Components to consider
        len_fold: int, length of each fold
        n_win: int, number of windows for the pooled regression
        temp_path: None or str, path for temp savings. If None, there are no
            temp savings. Default=None
        scaler_pre: str representing the scaler to use in preprocessing, either
            'Standard' or 'MinMax'. Other values will result in no scaling.
            Default='Standard'
        coll_threshold: float, correlation threshold for collinearity filter
        SEED: int, seed to set random values
        lasso_fold: int, number of folds for the cross validation. Default = 5
        min_rfs: int, minimum number of risk factors to be saved. Default = 2
        max_rfs: int, maximum number of risk factors to be saved. Default = 4
        n_round: int, number of decimals considered (if <=0, no round).Default=3
        scaler: str representing the scaler to use, either 'Standard' or
            'MinMax'. Other values will result in no scaling. Default='Standard'
        opt_hyper_port: dcit, hyperparameters for the minimizer, containing two
            keys: 'maxiter' and 'disp'. Default={'maxiter':200, 'disp':True}
        port_select: int, number of portfolios to select. Default=3
        verbose: bool, manages the verbosity. Default=True
    OUTPUT:
        target_portfolios: list, containing weights of the optimal portfolio
    '''
    from sklearn.preprocessing import MinMaxScaler, StandardScaler
    
    #----- From prices to returns
    X.index = pd.to_datetime(X.index)
    # Monthly returns
    XM = utils.DailyPrice2MonthlyReturn(X)
    # Daily returns
    XD = utils.DailyPrice2DailyReturn(X)
    # Scale data
    if scaler_pre == 'Standard':
        XD = pd.DataFrame( StandardScaler().fit_transform(XD.values),
                          index = XD.index, columns = XD.columns )
        XM = pd.DataFrame( StandardScaler().fit_transform(XM.values),
                          index = XM.index, columns = XM.columns )
    elif scaler_pre == 'MinMax':
        XD = pd.DataFrame( MinMaxScaler().fit_transform(XD.values),
                          index = XD.index, columns = XD.columns )
        XM = pd.DataFrame( MinMaxScaler().fit_transform(XM.values),
                          index = XM.index, columns = XM.columns )
    
    #----- Create Risk Factors
    if temp_path != None:
        try:
            PCs = pd.read_csv(f'{temp_path}/RiskFactors.csv', index_col=0)
            PCs.index = pd.to_datetime(PCs.index)
        except:
            PCs = risk_factors_nnpca_super_daily_only.CreateRiskFactors([XD, XM], n_pcs,
                                                 gran_names=['Daily','Monthly'],
                                                 threshold=coll_threshold,
                                                 SEED=SEED)
            PCs.to_csv(f'{temp_path}/RiskFactors.csv')
    else:
        PCs = risk_factors_nnpca_super_daily_only.CreateRiskFactors([XD, XM], n_pcs,
                                             gran_names=['Daily', 'Monthly'],
                                             threshold=coll_threshold,SEED=SEED)
    if verbose:
        print('Risk Factors successfully extracted!\n')

    #----- Apply Features Selection
    #Check if there are previous savings
    if temp_path != None:
        try:
            with open(f'{temp_path}/Saved_RFs.pickle','rb') as f:
                saved_rf = pickle.load(f)
        except:
            saved_rf = dict()
    else:
        saved_rf = dict()
    #Go on with features selection
    Grid = {'alpha':np.logspace(-11, -2, num=25, base=np.e),
        'tau':np.linspace(0.5, 1.5, 11)}
    
    cnt = 0
    for col in XD.columns[len(saved_rf.keys()):]:
        cnt += 1
        if verbose:
            print(f'Optimizing hyperparameters for asset {col}')
            print(f'Optimizing hyperparemeters for asset num {cnt} remaining {len(XD.columns[len(saved_rf.keys()):])}')

        flag, res = clustering.A_Lasso_Grid_Search(series=XD[col],
                                                   Exog=PCs.values,
                                                   grid=Grid,
                                                   n_fold=lasso_fold,
                                                   len_fold=len_fold,
                                                   min_rfs=min_rfs,
                                                   max_rfs=max_rfs,
                                                   scaler=scaler)
        #If the result is positive, store the hyperparameters
        if flag:
            saved_rf[col] = res
            if verbose:
                print(f'Optimization result: {res}')
        #Otherwise, make a new, more accurate search
        else:
            if res == -1:
                temp_Grid = {'alpha':np.logspace(-16, -11,num=25,base=np.e),
                            'tau':np.linspace(0.5, 1.5, 11)}
            elif res == 1:
                temp_Grid = {'alpha':np.logspace(-3, 3, num=25, base=np.e),
                            'tau':np.linspace(0.5, 1.5, 11)}
            else:
                temp_Grid = {'alpha':np.logspace(-11, -2,num=40,base=np.e),
                            'tau':np.linspace(0.5, 2, 20)}
            flag, res = clustering.A_Lasso_Grid_Search(series=XD[col],
                                                       Exog=PCs.values,
                                                       grid=temp_Grid,
                                                       n_fold=lasso_fold,
                                                       len_fold=len_fold,
                                                       min_rfs=min_rfs,
                                                       max_rfs=max_rfs,
                                                       scaler=scaler)
            if flag:
                saved_rf[col] = res
                if verbose:
                    print(f'Optimization result: {res}')
        if temp_path != None:
            with open(f'{temp_path}/Saved_RFs.pickle','wb') as f:
                pickle.dump(saved_rf, f)

    #----- Create Clustering
    #Create clusters
    clusters = clustering.Clustering(saved_rf)
    if verbose:
        print('Total clusters:')
        for n_clust, cluster in enumerate(clusters):
            print(f'Cluster {n_clust}, Risk factors: {cluster[0]},\
            Cluster Dimension: {len(cluster[1])}')
            print(f'Assets in the cluster: {cluster[1]}')
    #Save useful clusters
    clusters = clustering.UsefulClusters(clusters, saved_rf)
    if verbose:
        print('\nUseful clusters:')
        for n_clust, cluster in enumerate(clusters):
            print(f'Cluster {n_clust}, Risk factors: {cluster[0]}')
            print(f'Assets in the cluster: {cluster[1]}')

    #----- Investment Strategy
    target_portfolios = investment.Create_Portfolios(XD=XD, Exog=PCs.values,
                                        clusters=clusters,
                                        target_function=utils.Expected_Sharpe,
                                        windows_number=n_win,
                                        scaler=scaler, opt_hyper=opt_hyper_port,
                                        port_to_select=port_select)
    #Adjust portfolios weight to obtain one output portfolio
    for port in target_portfolios:
        port[1] = port[1]/port_select
    return target_portfolios

# %% [markdown]
# Modified code

# %%
import matplotlib.pyplot as plt
import pandas as pd 

path = 'data'
base_line_data = 'Dataset'
X = pd.read_csv(f'{path}/close_price.csv')
X['Date'] = X['Date'].apply(lambda x: pd.to_datetime(x).date())

X.set_index('Date', inplace=True)
X.index = pd.to_datetime(X.index)
print(X.index)
print(X.head())
X.dropna(axis=1, how='any', inplace=True)
X = X.iloc[:, :100]
print(X.head())
test_start = '2022-12-21'
XD = utils.DailyPrice2DailyReturn(X)
# Out:
# DatetimeIndex(['2016-01-04', '2016-01-05', '2016-01-06', '2016-01-07',
#                '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13',
#                '2016-01-14', '2016-01-15',
#                ...
#                '2023-08-17', '2023-08-18', '2023-08-21', '2023-08-22',
#                '2023-08-23', '2023-08-24', '2023-08-25', '2023-08-28',
#                '2023-08-29', '2023-08-30'],
#               dtype='datetime64[ns]', name='Date', length=1928, freq=None)
#                    MMM        AOS        ABT       ABBV       ABMD        ACN  \
# Date
# 2016-01-04  113.048523  33.202068  37.160885  41.186237  85.239998  89.974754
# 2016-01-05  113.541328  33.016586  37.152229  41.014664  85.000000  90.443031
# 2016-01-06  111.254501  32.362957  36.840607  41.021812  85.300003  90.266327
# 2016-01-07  108.544174  30.781895  35.957676  40.900269  81.919998  87.615585
# 2016-01-08  108.174561  29.686659  35.204590  39.785004  84.580002  86.767349
#
#                  ATVI        ADM       ADBE         AAP  ...  WLTW       WYNN  \
# Date                                                     ...
# 2016-01-04  35.592754  28.809200  91.970001  140.337891  ...   NaN  61.980740
# 2016-01-05  35.138618  29.130730  92.339996  139.379135  ...   NaN  63.152424
# 2016-01-06  34.807484  28.423363  91.019997  135.691879  ...   NaN  59.880779
# 2016-01-07  34.315502  27.748142  89.110001  137.194427  ...   NaN  54.247807
# 2016-01-08  33.785683  27.643644  87.849998  134.180084  ...   NaN  52.039684
#
#                   XEL  XLNX        XYL        YUM       ZBRA        ZBH  \
# Date
# 2016-01-04  28.352652   NaN  32.759193  44.992352  66.489998  93.003998
# 2016-01-05  28.638554   NaN  32.750130  44.880207  64.820000  94.940605
# 2016-01-06  28.940350   NaN  32.341530  44.562431  62.230000  95.351700
# 2016-01-07  29.051540   NaN  31.506205  43.042118  59.410000  93.159279
# 2016-01-08  28.733862   NaN  31.206579  42.456436  59.250000  92.766464
#
#                  ZION        ZTS
# Date
# 2016-01-04  22.009640  44.828045
# 2016-01-05  21.770666  45.529819
# 2016-01-06  21.136171  45.539299
# 2016-01-07  20.501677  44.154720
# 2016-01-08  20.270945  43.509850
#
# [5 rows x 505 columns]
#                    MMM        AOS        ABT       ABBV        ACN       ATVI  \
# Date
# 2016-01-04  113.048523  33.202068  37.160885  41.186237  89.974754  35.592754
# 2016-01-05  113.541328  33.016586  37.152229  41.014664  90.443031  35.138618
# 2016-01-06  111.254501  32.362957  36.840607  41.021812  90.266327  34.807484
# 2016-01-07  108.544174  30.781895  35.957676  40.900269  87.615585  34.315502
# 2016-01-08  108.174561  29.686659  35.204590  39.785004  86.767349  33.785683
#
#                   ADM       ADBE         AAP   AMD  ...        CNC        CNP  \
# Date                                                ...
# 2016-01-04  28.809200  91.970001  140.337891  2.77  ...  33.014999  13.929834
# 2016-01-05  29.130730  92.339996  139.379135  2.75  ...  33.485001  14.059447
# 2016-01-06  28.423363  91.019997  135.691879  2.51  ...  32.985001  13.884086
# 2016-01-07  27.748142  89.110001  137.194427  2.28  ...  31.785000  13.609608
# 2016-01-08  27.643644  87.849998  134.180084  2.14  ...  31.275000  13.579108
#
#                    CF        CRL       SCHW        CHTR        CVX  \
# Date
# 2016-01-04  32.163696  78.250000  29.105005  177.529999  63.882397
# 2016-01-05  31.155102  78.000000  29.013992  175.169998  64.428818
# 2016-01-06  28.462875  76.389999  28.021990  174.309998  61.883595
# 2016-01-07  27.112804  78.519997  26.556725  173.630005  59.690674
# 2016-01-08  26.858669  78.949997  26.392904  174.889999  59.050762
#
#                    CMG         CB        CHD
# Date
# 2016-01-04  448.809998  97.285385  37.609425
# 2016-01-05  449.029999  98.269073  37.289669
# 2016-01-06  426.670013  96.438507  37.114025
# 2016-01-07  416.000000  95.446243  36.515049
# 2016-01-08  413.290009  94.060478  36.956406
#
# [5 rows x 100 columns]

# %%
len(XD.columns)
# Out:
# 100

# %%
test_start_12fold = ['2022-09-01', 
                     '2022-10-01', 
                     '2022-11-01', 
                     '2022-12-01', 
                     '2023-01-01', 
                     '2023-02-01', 
                     '2023-03-01', 
                     '2023-04-01', 
                     '2023-05-01', 
                     '2023-06-01', 
                     '2023-07-01', 
                     '2023-08-01',
                     '2023-09-01']

# %% [markdown]
# Training and Testing

# %%
portfolios = []
for i in range (12):
    print("fold: ", i)
    X_test = XD[ XD.index >= test_start_12fold[i]]
    X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
    X_each_fold = X[ X.index < test_start_12fold[i] ]
    #Obtain portfolio value in the test set
    target_portfolio = An_Unsupervised_Learning_Framework(X_each_fold, n_pcs=7,
                                                            len_fold=42, n_win=50)
    portfolios.append(target_portfolio)
# Out:
# fold:  0
# 53/53 [==============================] - 0s 2ms/step
# Risk Factors successfully extracted!
#
# Optimizing hyperparameters for asset MMM
# Optimizing hyperparemeters for asset num 1 remaining 100
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset AOS
# Optimizing hyperparemeters for asset num 2 remaining 99
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset ABT
# Optimizing hyperparemeters for asset num 3 remaining 98
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ABBV
# Optimizing hyperparemeters for asset num 4 remaining 97
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ACN
# Optimizing hyperparemeters for asset num 5 remaining 96
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset ATVI
# Optimizing hyperparemeters for asset num 6 remaining 95
# Optimization result: [1, 3, 5]
# Optimizing hyperparameters for asset ADM
# Optimizing hyperparemeters for asset num 7 remaining 94
# Optimization result: [1, 3, 4, 5]
# Optimizing hyperparameters for asset ADBE
# Optimizing hyperparemeters for asset num 8 remaining 93
# Optimization result: [1, 3, 5]
# Optimizing hyperparameters for asset AAP
# Optimizing hyperparemeters for asset num 9 remaining 92
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset AMD
# Optimizing hyperparemeters for asset num 10 remaining 91
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset AES
# Optimizing hyperparemeters for asset num 11 remaining 90
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset AFL
# Optimizing hyperparemeters for asset num 12 remaining 89
# Optimization result: [2, 3, 4, 5]
# Optimizing hyperparameters for asset A
# Optimizing hyperparemeters for asset num 13 remaining 88
# Optimization result: [1, 3, 5, 6]
# Optimizing hyperparameters for asset APD
# Optimizing hyperparemeters for asset num 14 remaining 87
# Optimization result: [1, 5, 6]
# Optimizing hyperparameters for asset AKAM
# Optimizing hyperparemeters for asset num 15 remaining 86
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset ALK
# Optimizing hyperparemeters for asset num 16 remaining 85
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset ALB
# Optimizing hyperparemeters for asset num 17 remaining 84
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset ARE
# Optimizing hyperparemeters for asset num 18 remaining 83
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ALGN
# Optimizing hyperparemeters for asset num 19 remaining 82
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset ALLE
# Optimizing hyperparemeters for asset num 20 remaining 81
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset LNT
# Optimizing hyperparemeters for asset num 21 remaining 80
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset ALL
# Optimizing hyperparemeters for asset num 22 remaining 79
# Optimization result: [3, 4, 5, 6]
# Optimizing hyperparameters for asset GOOGL
# Optimizing hyperparemeters for asset num 23 remaining 78
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset GOOG
# Optimizing hyperparemeters for asset num 24 remaining 77
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset MO
# Optimizing hyperparemeters for asset num 25 remaining 76
# Optimization result: [3, 5]
# Optimizing hyperparameters for asset AMZN
# Optimizing hyperparemeters for asset num 26 remaining 75
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset AMCR
# Optimizing hyperparemeters for asset num 27 remaining 74
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset AEE
# Optimizing hyperparemeters for asset num 28 remaining 73
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset AAL
# Optimizing hyperparemeters for asset num 29 remaining 72
# Optimization result: [4, 5, 6]
# Optimizing hyperparameters for asset AEP
# Optimizing hyperparemeters for asset num 30 remaining 71
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset AXP
# Optimizing hyperparemeters for asset num 31 remaining 70
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset AIG
# Optimizing hyperparemeters for asset num 32 remaining 69
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset AMT
# Optimizing hyperparemeters for asset num 33 remaining 68
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AWK
# Optimizing hyperparemeters for asset num 34 remaining 67
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset AMP
# Optimizing hyperparemeters for asset num 35 remaining 66
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset ABC
# Optimizing hyperparemeters for asset num 36 remaining 65
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset AME
# Optimizing hyperparemeters for asset num 37 remaining 64
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset AMGN
# Optimizing hyperparemeters for asset num 38 remaining 63
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset APH
# Optimizing hyperparemeters for asset num 39 remaining 62
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset ADI
# Optimizing hyperparemeters for asset num 40 remaining 61
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset ANSS
# Optimizing hyperparemeters for asset num 41 remaining 60
# Optimization result: [1, 3, 5]
# Optimizing hyperparameters for asset AON
# Optimizing hyperparemeters for asset num 42 remaining 59
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset APA
# Optimizing hyperparemeters for asset num 43 remaining 58
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset AAPL
# Optimizing hyperparemeters for asset num 44 remaining 57
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset AMAT
# Optimizing hyperparemeters for asset num 45 remaining 56
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset APTV
# Optimizing hyperparemeters for asset num 46 remaining 55
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset ANET
# Optimizing hyperparemeters for asset num 47 remaining 54
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset AJG
# Optimizing hyperparemeters for asset num 48 remaining 53
# Optimization result: [4, 5, 6]
# Optimizing hyperparameters for asset AIZ
# Optimizing hyperparemeters for asset num 49 remaining 52
# Optimization result: [3, 4, 5, 6]
# Optimizing hyperparameters for asset T
# Optimizing hyperparemeters for asset num 50 remaining 51
# Optimization result: [1, 3, 5, 6]
# Optimizing hyperparameters for asset ATO
# Optimizing hyperparemeters for asset num 51 remaining 50
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset ADSK
# Optimizing hyperparemeters for asset num 52 remaining 49
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset ADP
# Optimizing hyperparemeters for asset num 53 remaining 48
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset AZO
# Optimizing hyperparemeters for asset num 54 remaining 47
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset AVB
# Optimizing hyperparemeters for asset num 55 remaining 46
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset AVY
# Optimizing hyperparemeters for asset num 56 remaining 45
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset BKR
# Optimizing hyperparemeters for asset num 57 remaining 44
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset BAC
# Optimizing hyperparemeters for asset num 58 remaining 43
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset BBWI
# Optimizing hyperparemeters for asset num 59 remaining 42
# Optimization result: [1, 3, 4, 5]
# Optimizing hyperparameters for asset BAX
# Optimizing hyperparemeters for asset num 60 remaining 41
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset BDX
# Optimizing hyperparemeters for asset num 61 remaining 40
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset BBY
# Optimizing hyperparemeters for asset num 62 remaining 39
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset BIO
# Optimizing hyperparemeters for asset num 63 remaining 38
# Optimization result: [1, 3, 5, 6]
# Optimizing hyperparameters for asset TECH
# Optimizing hyperparemeters for asset num 64 remaining 37
# Optimization result: [1, 3, 5]
# Optimizing hyperparameters for asset BIIB
# Optimizing hyperparemeters for asset num 65 remaining 36
# Optimization result: [3, 5]
# Optimizing hyperparameters for asset BLK
# Optimizing hyperparemeters for asset num 66 remaining 35
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset BK
# Optimizing hyperparemeters for asset num 67 remaining 34
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset BA
# Optimizing hyperparemeters for asset num 68 remaining 33
# Optimization result: [2, 3, 4, 5]
# Optimizing hyperparameters for asset BKNG
# Optimizing hyperparemeters for asset num 69 remaining 32
# Optimization result: [1, 3, 4, 5]
# Optimizing hyperparameters for asset BWA
# Optimizing hyperparemeters for asset num 70 remaining 31
# Optimization result: [4, 5, 6]
# Optimizing hyperparameters for asset BXP
# Optimizing hyperparemeters for asset num 71 remaining 30
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset BSX
# Optimizing hyperparemeters for asset num 72 remaining 29
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset BMY
# Optimizing hyperparemeters for asset num 73 remaining 28
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset AVGO
# Optimizing hyperparemeters for asset num 74 remaining 27
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset BR
# Optimizing hyperparemeters for asset num 75 remaining 26
# Optimization result: [1, 5, 6]
# Optimizing hyperparameters for asset BRO
# Optimizing hyperparemeters for asset num 76 remaining 25
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset CHRW
# Optimizing hyperparemeters for asset num 77 remaining 24
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CDNS
# Optimizing hyperparemeters for asset num 78 remaining 23
# Optimization result: [1, 3, 5]
# Optimizing hyperparameters for asset CZR
# Optimizing hyperparemeters for asset num 79 remaining 22
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CPB
# Optimizing hyperparemeters for asset num 80 remaining 21
# Optimization result: [4, 5, 6]
# Optimizing hyperparameters for asset COF
# Optimizing hyperparemeters for asset num 81 remaining 20
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset CAH
# Optimizing hyperparemeters for asset num 82 remaining 19
# Optimization result: [1, 2, 3, 5]
# Optimizing hyperparameters for asset KMX
# Optimizing hyperparemeters for asset num 83 remaining 18
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CCL
# Optimizing hyperparemeters for asset num 84 remaining 17
# Optimization result: [3, 4, 5]
# Optimizing hyperparameters for asset CTLT
# Optimizing hyperparemeters for asset num 85 remaining 16
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CAT
# Optimizing hyperparemeters for asset num 86 remaining 15
# Optimization result: [1, 4, 5, 6]
# Optimizing hyperparameters for asset CBOE
# Optimizing hyperparemeters for asset num 87 remaining 14
# Optimization result: [1, 3, 5, 6]
# Optimizing hyperparameters for asset CBRE
# Optimizing hyperparemeters for asset num 88 remaining 13
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CDW
# Optimizing hyperparemeters for asset num 89 remaining 12
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CE
# Optimizing hyperparemeters for asset num 90 remaining 11
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CNC
# Optimizing hyperparemeters for asset num 91 remaining 10
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset CNP
# Optimizing hyperparemeters for asset num 92 remaining 9
# Optimization result: [3, 5, 6]
# Optimizing hyperparameters for asset CF
# Optimizing hyperparemeters for asset num 93 remaining 8
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset CRL
# Optimizing hyperparemeters for asset num 94 remaining 7
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset SCHW
# Optimizing hyperparemeters for asset num 95 remaining 6
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CHTR
# Optimizing hyperparemeters for asset num 96 remaining 5
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset CVX
# Optimizing hyperparemeters for asset num 97 remaining 4
# Optimization result: [2, 3, 4, 5]
# Optimizing hyperparameters for asset CMG
# Optimizing hyperparemeters for asset num 98 remaining 3
# Optimization result: [1, 3, 4, 5]
# Optimizing hyperparameters for asset CB
# Optimizing hyperparemeters for asset num 99 remaining 2
# Optimization result: [3, 4, 5, 6]
# Optimizing hyperparameters for asset CHD
# Optimizing hyperparemeters for asset num 100 remaining 1
# Optimization result: [4, 5, 6]
# Total clusters:
# Cluster 0, Risk factors: [1, 5],            Cluster Dimension: 21
# Assets in the cluster: ['MMM', 'AOS', 'AMD', 'AKAM', 'ALLE', 'GOOGL', 'GOOG', 'AMZN', 'ADI', 'AAPL', 'ANET', 'ADSK', 'AVY', 'BBY', 'BLK', 'AVGO', 'CHRW', 'CTLT', 'CDW', 'CRL', 'SCHW']
# Cluster 1, Risk factors: [5, 6],            Cluster Dimension: 12
# Assets in the cluster: ['ABT', 'ABBV', 'ARE', 'AWK', 'AMGN', 'ADP', 'BAX', 'BDX', 'BMY', 'CNC', 'CF', 'CHTR']
# Cluster 2, Risk factors: [1, 4, 5, 6],            Cluster Dimension: 7
# Assets in the cluster: ['ACN', 'ALB', 'APH', 'AON', 'AZO', 'BSX', 'CAT']
# Cluster 3, Risk factors: [1, 3, 5],            Cluster Dimension: 5
# Assets in the cluster: ['ATVI', 'ADBE', 'ANSS', 'TECH', 'CDNS']
# Cluster 4, Risk factors: [1, 3, 4, 5],            Cluster Dimension: 4
# Assets in the cluster: ['ADM', 'BBWI', 'BKNG', 'CMG']
# Cluster 5, Risk factors: [1, 4, 5],            Cluster Dimension: 4
# Assets in the cluster: ['AAP', 'ALGN', 'AME', 'AMAT']
# Cluster 6, Risk factors: [4, 5],            Cluster Dimension: 11
# Assets in the cluster: ['AES', 'AMCR', 'AMP', 'APA', 'APTV', 'BKR', 'BAC', 'CZR', 'KMX', 'CBRE', 'CE']
# Cluster 7, Risk factors: [2, 3, 4, 5],            Cluster Dimension: 3
# Assets in the cluster: ['AFL', 'BA', 'CVX']
# Cluster 8, Risk factors: [1, 3, 5, 6],            Cluster Dimension: 4
# Assets in the cluster: ['A', 'T', 'BIO', 'CBOE']
# Cluster 9, Risk factors: [1, 5, 6],            Cluster Dimension: 2
# Assets in the cluster: ['APD', 'BR']
# Cluster 10, Risk factors: [3, 4, 5],            Cluster Dimension: 7
# Assets in the cluster: ['ALK', 'AXP', 'AIG', 'BK', 'BXP', 'COF', 'CCL']
# Cluster 11, Risk factors: [3, 5, 6],            Cluster Dimension: 6
# Assets in the cluster: ['LNT', 'AEE', 'AEP', 'ATO', 'AVB', 'CNP']
# Cluster 12, Risk factors: [3, 4, 5, 6],            Cluster Dimension: 3
# Assets in the cluster: ['ALL', 'AIZ', 'CB']
# Cluster 13, Risk factors: [3, 5],            Cluster Dimension: 2
# Assets in the cluster: ['MO', 'BIIB']
# Cluster 14, Risk factors: [4, 5, 6],            Cluster Dimension: 5
# Assets in the cluster: ['AAL', 'AJG', 'BWA', 'CPB', 'CHD']
# Cluster 15, Risk factors: [2, 5, 6],            Cluster Dimension: 1
# Assets in the cluster: ['AMT']
# Cluster 16, Risk factors: [1, 2, 5, 6],            Cluster Dimension: 2
# Assets in the cluster: ['ABC', 'BRO']
# Cluster 17, Risk factors: [1, 2, 3, 5],            Cluster Dimension: 1
# Assets in the cluster: ['CAH']
#
# Useful clusters:
# Cluster 0, Risk factors: [1, 5]
# Assets in the cluster: ['MMM', 'AOS', 'AMD', 'AKAM', 'ALLE', 'GOOGL', 'GOOG', 'AMZN', 'ADI', 'AAPL', 'ANET', 'ADSK', 'AVY', 'BBY', 'BLK', 'AVGO', 'CHRW', 'CTLT', 'CDW', 'CRL', 'SCHW']
# Cluster 1, Risk factors: [5, 6]
# Assets in the cluster: ['ABT', 'ABBV', 'ARE', 'AWK', 'AMGN', 'ADP', 'BAX', 'BDX', 'BMY', 'CNC', 'CF', 'CHTR']
# Cluster 2, Risk factors: [1, 4, 5, 6]
# Assets in the cluster: ['ACN', 'ALB', 'APH', 'AON', 'AZO', 'BSX', 'CAT']
# Cluster 3, Risk factors: [1, 3, 5]
# Assets in the cluster: ['ATVI', 'ADBE', 'ANSS', 'TECH', 'CDNS']
# Cluster 4, Risk factors: [1, 4, 5]
# Assets in the cluster: ['AAP', 'ALGN', 'AME', 'AMAT']
# Cluster 5, Risk factors: [4, 5]
# Assets in the cluster: ['AES', 'AMCR', 'AMP', 'APA', 'APTV', 'BKR', 'BAC', 'CZR', 'KMX', 'CBRE', 'CE']
# Cluster 6, Risk factors: [3, 4, 5]
# Assets in the cluster: ['ALK', 'AXP', 'AIG', 'BK', 'BXP', 'COF', 'CCL']
# Cluster 7, Risk factors: [3, 5, 6]
# Assets in the cluster: ['LNT', 'AEE', 'AEP', 'ATO', 'AVB', 'CNP']
# Cluster 8, Risk factors: [4, 5, 6]
# Assets in the cluster: ['AAL', 'AJG', 'BWA', 'CPB', 'CHD']
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -7.416120431552978e+20
#             Iterations: 3
#             Function evaluations: 66
#             Gradient evaluations: 3
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -42477661967.17327
#             Iterations: 6
#             Function evaluations: 26
#             Gradient evaluations: 2
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.6032284742298625
#             Iterations: 38
#             Function evaluations: 391
#             Gradient evaluations: 38
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -4494903.75847077
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 1
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.3885161404641801
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -664502789.7643312
#             Iterations: 2
#             Function evaluations: 24
#             Gradient evaluations: 2
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.6515281688100386
#             Iterations: 56
#             Function evaluations: 581
#             Gradient evaluations: 56
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.7250601940439422
#             Iterations: 45
#             Function evaluations: 349
#             Gradient evaluations: 45
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -3.7864962842370047
#             Iterations: 21
#             Function evaluations: 166
#             Gradient evaluations: 21
# fold:  1
# 54/54 [==============================] - 0s 2ms/step
# Risk Factors successfully extracted!
#
# Optimizing hyperparameters for asset MMM
# Optimizing hyperparemeters for asset num 1 remaining 100
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AOS
# Optimizing hyperparemeters for asset num 2 remaining 99
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ABT
# Optimizing hyperparemeters for asset num 3 remaining 98
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ABBV
# Optimizing hyperparemeters for asset num 4 remaining 97
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ACN
# Optimizing hyperparemeters for asset num 5 remaining 96
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ATVI
# Optimizing hyperparemeters for asset num 6 remaining 95
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset ADM
# Optimizing hyperparemeters for asset num 7 remaining 94
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ADBE
# Optimizing hyperparemeters for asset num 8 remaining 93
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AAP
# Optimizing hyperparemeters for asset num 9 remaining 92
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AMD
# Optimizing hyperparemeters for asset num 10 remaining 91
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset AES
# Optimizing hyperparemeters for asset num 11 remaining 90
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AFL
# Optimizing hyperparemeters for asset num 12 remaining 89
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset A
# Optimizing hyperparemeters for asset num 13 remaining 88
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset APD
# Optimizing hyperparemeters for asset num 14 remaining 87
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AKAM
# Optimizing hyperparemeters for asset num 15 remaining 86
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ALK
# Optimizing hyperparemeters for asset num 16 remaining 85
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset ALB
# Optimizing hyperparemeters for asset num 17 remaining 84
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset ARE
# Optimizing hyperparemeters for asset num 18 remaining 83
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ALGN
# Optimizing hyperparemeters for asset num 19 remaining 82
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ALLE
# Optimizing hyperparemeters for asset num 20 remaining 81
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset LNT
# Optimizing hyperparemeters for asset num 21 remaining 80
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ALL
# Optimizing hyperparemeters for asset num 22 remaining 79
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset GOOGL
# Optimizing hyperparemeters for asset num 23 remaining 78
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset GOOG
# Optimizing hyperparemeters for asset num 24 remaining 77
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset MO
# Optimizing hyperparemeters for asset num 25 remaining 76
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AMZN
# Optimizing hyperparemeters for asset num 26 remaining 75
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AMCR
# Optimizing hyperparemeters for asset num 27 remaining 74
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AEE
# Optimizing hyperparemeters for asset num 28 remaining 73
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AAL
# Optimizing hyperparemeters for asset num 29 remaining 72
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset AEP
# Optimizing hyperparemeters for asset num 30 remaining 71
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AXP
# Optimizing hyperparemeters for asset num 31 remaining 70
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AIG
# Optimizing hyperparemeters for asset num 32 remaining 69
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AMT
# Optimizing hyperparemeters for asset num 33 remaining 68
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AWK
# Optimizing hyperparemeters for asset num 34 remaining 67
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AMP
# Optimizing hyperparemeters for asset num 35 remaining 66
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ABC
# Optimizing hyperparemeters for asset num 36 remaining 65
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset AME
# Optimizing hyperparemeters for asset num 37 remaining 64
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AMGN
# Optimizing hyperparemeters for asset num 38 remaining 63
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset APH
# Optimizing hyperparemeters for asset num 39 remaining 62
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ADI
# Optimizing hyperparemeters for asset num 40 remaining 61
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset ANSS
# Optimizing hyperparemeters for asset num 41 remaining 60
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset AON
# Optimizing hyperparemeters for asset num 42 remaining 59
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset APA
# Optimizing hyperparemeters for asset num 43 remaining 58
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AAPL
# Optimizing hyperparemeters for asset num 44 remaining 57
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AMAT
# Optimizing hyperparemeters for asset num 45 remaining 56
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset APTV
# Optimizing hyperparemeters for asset num 46 remaining 55
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ANET
# Optimizing hyperparemeters for asset num 47 remaining 54
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset AJG
# Optimizing hyperparemeters for asset num 48 remaining 53
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AIZ
# Optimizing hyperparemeters for asset num 49 remaining 52
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset T
# Optimizing hyperparemeters for asset num 50 remaining 51
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ATO
# Optimizing hyperparemeters for asset num 51 remaining 50
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset ADSK
# Optimizing hyperparemeters for asset num 52 remaining 49
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset ADP
# Optimizing hyperparemeters for asset num 53 remaining 48
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AZO
# Optimizing hyperparemeters for asset num 54 remaining 47
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AVB
# Optimizing hyperparemeters for asset num 55 remaining 46
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset AVY
# Optimizing hyperparemeters for asset num 56 remaining 45
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset BKR
# Optimizing hyperparemeters for asset num 57 remaining 44
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BAC
# Optimizing hyperparemeters for asset num 58 remaining 43
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset BBWI
# Optimizing hyperparemeters for asset num 59 remaining 42
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset BAX
# Optimizing hyperparemeters for asset num 60 remaining 41
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset BDX
# Optimizing hyperparemeters for asset num 61 remaining 40
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BBY
# Optimizing hyperparemeters for asset num 62 remaining 39
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BIO
# Optimizing hyperparemeters for asset num 63 remaining 38
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset TECH
# Optimizing hyperparemeters for asset num 64 remaining 37
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset BIIB
# Optimizing hyperparemeters for asset num 65 remaining 36
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset BLK
# Optimizing hyperparemeters for asset num 66 remaining 35
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BK
# Optimizing hyperparemeters for asset num 67 remaining 34
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset BA
# Optimizing hyperparemeters for asset num 68 remaining 33
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset BKNG
# Optimizing hyperparemeters for asset num 69 remaining 32
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BWA
# Optimizing hyperparemeters for asset num 70 remaining 31
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BXP
# Optimizing hyperparemeters for asset num 71 remaining 30
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset BSX
# Optimizing hyperparemeters for asset num 72 remaining 29
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BMY
# Optimizing hyperparemeters for asset num 73 remaining 28
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset AVGO
# Optimizing hyperparemeters for asset num 74 remaining 27
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset BR
# Optimizing hyperparemeters for asset num 75 remaining 26
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset BRO
# Optimizing hyperparemeters for asset num 76 remaining 25
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CHRW
# Optimizing hyperparemeters for asset num 77 remaining 24
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CDNS
# Optimizing hyperparemeters for asset num 78 remaining 23
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset CZR
# Optimizing hyperparemeters for asset num 79 remaining 22
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CPB
# Optimizing hyperparemeters for asset num 80 remaining 21
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset COF
# Optimizing hyperparemeters for asset num 81 remaining 20
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset CAH
# Optimizing hyperparemeters for asset num 82 remaining 19
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset KMX
# Optimizing hyperparemeters for asset num 83 remaining 18
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CCL
# Optimizing hyperparemeters for asset num 84 remaining 17
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset CTLT
# Optimizing hyperparemeters for asset num 85 remaining 16
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset CAT
# Optimizing hyperparemeters for asset num 86 remaining 15
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset CBOE
# Optimizing hyperparemeters for asset num 87 remaining 14
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CBRE
# Optimizing hyperparemeters for asset num 88 remaining 13
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CDW
# Optimizing hyperparemeters for asset num 89 remaining 12
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CE
# Optimizing hyperparemeters for asset num 90 remaining 11
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset CNC
# Optimizing hyperparemeters for asset num 91 remaining 10
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset CNP
# Optimizing hyperparemeters for asset num 92 remaining 9
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CF
# Optimizing hyperparemeters for asset num 93 remaining 8
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset CRL
# Optimizing hyperparemeters for asset num 94 remaining 7
# Optimization result: [5, 6]
# Optimizing hyperparameters for asset SCHW
# Optimizing hyperparemeters for asset num 95 remaining 6
# Optimization result: [2, 5]
# Optimizing hyperparameters for asset CHTR
# Optimizing hyperparemeters for asset num 96 remaining 5
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CVX
# Optimizing hyperparemeters for asset num 97 remaining 4
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CMG
# Optimizing hyperparemeters for asset num 98 remaining 3
# Optimization result: [2, 5, 6]
# Optimizing hyperparameters for asset CB
# Optimizing hyperparemeters for asset num 99 remaining 2
# Optimization result: [2, 6]
# Optimizing hyperparameters for asset CHD
# Optimizing hyperparemeters for asset num 100 remaining 1
# Optimization result: [2, 5, 6]
# Total clusters:
# Cluster 0, Risk factors: [2, 5, 6],            Cluster Dimension: 24
# Assets in the cluster: ['MMM', 'ATVI', 'ADBE', 'AES', 'ALK', 'ALB', 'ALL', 'AWK', 'APA', 'AAPL', 'ANET', 'ADSK', 'AVY', 'BAC', 'BAX', 'BXP', 'AVGO', 'CAH', 'CTLT', 'CE', 'CNC', 'CF', 'CMG', 'CHD']
# Cluster 1, Risk factors: [2, 6],            Cluster Dimension: 52
# Assets in the cluster: ['AOS', 'ABT', 'ABBV', 'ACN', 'ADM', 'AAP', 'AFL', 'APD', 'ARE', 'ALLE', 'LNT', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AMP', 'AME', 'AMGN', 'APH', 'AON', 'APTV', 'AJG', 'AIZ', 'T', 'ATO', 'ADP', 'AZO', 'AVB', 'BKR', 'BDX', 'BBY', 'BLK', 'BKNG', 'BWA', 'BSX', 'BR', 'BRO', 'CHRW', 'CZR', 'CPB', 'KMX', 'CBOE', 'CBRE', 'CDW', 'CNP', 'CHTR', 'CVX', 'CB']
# Cluster 2, Risk factors: [5, 6],            Cluster Dimension: 14
# Assets in the cluster: ['AMD', 'A', 'AKAM', 'ALGN', 'GOOGL', 'GOOG', 'ADI', 'ANSS', 'AMAT', 'BIO', 'TECH', 'BIIB', 'CDNS', 'CRL']
# Cluster 3, Risk factors: [2, 5],            Cluster Dimension: 10
# Assets in the cluster: ['AAL', 'ABC', 'BBWI', 'BK', 'BA', 'BMY', 'COF', 'CCL', 'CAT', 'SCHW']
#
# Useful clusters:
# Cluster 0, Risk factors: [2, 5, 6]
# Assets in the cluster: ['MMM', 'ATVI', 'ADBE', 'AES', 'ALK', 'ALB', 'ALL', 'AWK', 'APA', 'AAPL', 'ANET', 'ADSK', 'AVY', 'BAC', 'BAX', 'BXP', 'AVGO', 'CAH', 'CTLT', 'CE', 'CNC', 'CF', 'CMG', 'CHD']
# Cluster 1, Risk factors: [2, 6]
# Assets in the cluster: ['AOS', 'ABT', 'ABBV', 'ACN', 'ADM', 'AAP', 'AFL', 'APD', 'ARE', 'ALLE', 'LNT', 'MO', 'AMZN', 'AMCR', 'AEE', 'AEP', 'AXP', 'AIG', 'AMT', 'AMP', 'AME', 'AMGN', 'APH', 'AON', 'APTV', 'AJG', 'AIZ', 'T', 'ATO', 'ADP', 'AZO', 'AVB', 'BKR', 'BDX', 'BBY', 'BLK', 'BKNG', 'BWA', 'BSX', 'BR', 'BRO', 'CHRW', 'CZR', 'CPB', 'KMX', 'CBOE', 'CBRE', 'CDW', 'CNP', 'CHTR', 'CVX', 'CB']
# Cluster 2, Risk factors: [5, 6]
# Assets in the cluster: ['AMD', 'A', 'AKAM', 'ALGN', 'GOOGL', 'GOOG', 'ADI', 'ANSS', 'AMAT', 'BIO', 'TECH', 'BIIB', 'CDNS', 'CRL']
# Cluster 3, Risk factors: [2, 5]
# Assets in the cluster: ['AAL', 'ABC', 'BBWI', 'BK', 'BA', 'BMY', 'COF', 'CCL', 'CAT', 'SCHW']
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -16050803016.58422
#             Iterations: 4
#             Function evaluations: 76
#             Gradient evaluations: 3
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -2.4673605422588185e+25
#             Iterations: 5
#             Function evaluations: 212
#             Gradient evaluations: 4
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -66621460.981264
#             Iterations: 6
#             Function evaluations: 30
#             Gradient evaluations: 2
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.6828179992246424
#             Iterations: 125
#             Function evaluations: 1623
#             Gradient evaluations: 125
# fold:  2
# 54/54 [==============================] - 0s 2ms/step
# Risk Factors successfully extracted!
#
# Optimizing hyperparameters for asset MMM
# Optimizing hyperparemeters for asset num 1 remaining 100
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2854: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\xul14\anaconda3\lib\site-packages\numpy\lib\function_base.py:2855: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AOS
# Optimizing hyperparemeters for asset num 2 remaining 99
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset ABT
# Optimizing hyperparemeters for asset num 3 remaining 98
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset ABBV
# Optimizing hyperparemeters for asset num 4 remaining 97
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset ACN
# Optimizing hyperparemeters for asset num 5 remaining 96
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset ATVI
# Optimizing hyperparemeters for asset num 6 remaining 95
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset ADM
# Optimizing hyperparemeters for asset num 7 remaining 94
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset ADBE
# Optimizing hyperparemeters for asset num 8 remaining 93
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset AAP
# Optimizing hyperparemeters for asset num 9 remaining 92
# Optimization result: [2, 4, 5]
# Optimizing hyperparameters for asset AMD
# Optimizing hyperparemeters for asset num 10 remaining 91
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AES
# Optimizing hyperparemeters for asset num 11 remaining 90
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset AFL
# Optimizing hyperparemeters for asset num 12 remaining 89
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset A
# Optimizing hyperparemeters for asset num 13 remaining 88
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset APD
# Optimizing hyperparemeters for asset num 14 remaining 87
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset AKAM
# Optimizing hyperparemeters for asset num 15 remaining 86
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset ALK
# Optimizing hyperparemeters for asset num 16 remaining 85
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset ALB
# Optimizing hyperparemeters for asset num 17 remaining 84
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset ARE
# Optimizing hyperparemeters for asset num 18 remaining 83
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset ALGN
# Optimizing hyperparemeters for asset num 19 remaining 82
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset ALLE
# Optimizing hyperparemeters for asset num 20 remaining 81
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset LNT
# Optimizing hyperparemeters for asset num 21 remaining 80
# Optimization result: [2, 4, 5]
# Optimizing hyperparameters for asset ALL
# Optimizing hyperparemeters for asset num 22 remaining 79
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset GOOGL
# Optimizing hyperparemeters for asset num 23 remaining 78
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset GOOG
# Optimizing hyperparemeters for asset num 24 remaining 77
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset MO
# Optimizing hyperparemeters for asset num 25 remaining 76
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset AMZN
# Optimizing hyperparemeters for asset num 26 remaining 75
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AMCR
# Optimizing hyperparemeters for asset num 27 remaining 74
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset AEE
# Optimizing hyperparemeters for asset num 28 remaining 73
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AAL
# Optimizing hyperparemeters for asset num 29 remaining 72
# Optimization result: [1, 2, 5]
# Optimizing hyperparameters for asset AEP
# Optimizing hyperparemeters for asset num 30 remaining 71
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AXP
# Optimizing hyperparemeters for asset num 31 remaining 70
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset AIG
# Optimizing hyperparemeters for asset num 32 remaining 69
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset AMT
# Optimizing hyperparemeters for asset num 33 remaining 68
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AWK
# Optimizing hyperparemeters for asset num 34 remaining 67
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AMP
# Optimizing hyperparemeters for asset num 35 remaining 66
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset ABC
# Optimizing hyperparemeters for asset num 36 remaining 65
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset AME
# Optimizing hyperparemeters for asset num 37 remaining 64
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AMGN
# Optimizing hyperparemeters for asset num 38 remaining 63
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset APH
# Optimizing hyperparemeters for asset num 39 remaining 62
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset ADI
# Optimizing hyperparemeters for asset num 40 remaining 61
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset ANSS
# Optimizing hyperparemeters for asset num 41 remaining 60
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset AON
# Optimizing hyperparemeters for asset num 42 remaining 59
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset APA
# Optimizing hyperparemeters for asset num 43 remaining 58
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AAPL
# Optimizing hyperparemeters for asset num 44 remaining 57
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AMAT
# Optimizing hyperparemeters for asset num 45 remaining 56
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset APTV
# Optimizing hyperparemeters for asset num 46 remaining 55
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset ANET
# Optimizing hyperparemeters for asset num 47 remaining 54
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AJG
# Optimizing hyperparemeters for asset num 48 remaining 53
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset AIZ
# Optimizing hyperparemeters for asset num 49 remaining 52
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset T
# Optimizing hyperparemeters for asset num 50 remaining 51
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset ATO
# Optimizing hyperparemeters for asset num 51 remaining 50
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset ADSK
# Optimizing hyperparemeters for asset num 52 remaining 49
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset ADP
# Optimizing hyperparemeters for asset num 53 remaining 48
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AZO
# Optimizing hyperparemeters for asset num 54 remaining 47
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset AVB
# Optimizing hyperparemeters for asset num 55 remaining 46
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset AVY
# Optimizing hyperparemeters for asset num 56 remaining 45
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset BKR
# Optimizing hyperparemeters for asset num 57 remaining 44
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BAC
# Optimizing hyperparemeters for asset num 58 remaining 43
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BBWI
# Optimizing hyperparemeters for asset num 59 remaining 42
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BAX
# Optimizing hyperparemeters for asset num 60 remaining 41
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BDX
# Optimizing hyperparemeters for asset num 61 remaining 40
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BBY
# Optimizing hyperparemeters for asset num 62 remaining 39
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BIO
# Optimizing hyperparemeters for asset num 63 remaining 38
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset TECH
# Optimizing hyperparemeters for asset num 64 remaining 37
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BIIB
# Optimizing hyperparemeters for asset num 65 remaining 36
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset BLK
# Optimizing hyperparemeters for asset num 66 remaining 35
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BK
# Optimizing hyperparemeters for asset num 67 remaining 34
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BA
# Optimizing hyperparemeters for asset num 68 remaining 33
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BKNG
# Optimizing hyperparemeters for asset num 69 remaining 32
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset BWA
# Optimizing hyperparemeters for asset num 70 remaining 31
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BXP
# Optimizing hyperparemeters for asset num 71 remaining 30
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset BSX
# Optimizing hyperparemeters for asset num 72 remaining 29
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset BMY
# Optimizing hyperparemeters for asset num 73 remaining 28
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset AVGO
# Optimizing hyperparemeters for asset num 74 remaining 27
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset BR
# Optimizing hyperparemeters for asset num 75 remaining 26
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset BRO
# Optimizing hyperparemeters for asset num 76 remaining 25
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset CHRW
# Optimizing hyperparemeters for asset num 77 remaining 24
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CDNS
# Optimizing hyperparemeters for asset num 78 remaining 23
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CZR
# Optimizing hyperparemeters for asset num 79 remaining 22
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CPB
# Optimizing hyperparemeters for asset num 80 remaining 21
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset COF
# Optimizing hyperparemeters for asset num 81 remaining 20
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CAH
# Optimizing hyperparemeters for asset num 82 remaining 19
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset KMX
# Optimizing hyperparemeters for asset num 83 remaining 18
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CCL
# Optimizing hyperparemeters for asset num 84 remaining 17
# Optimization result: [1, 2, 5]
# Optimizing hyperparameters for asset CTLT
# Optimizing hyperparemeters for asset num 85 remaining 16
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset CAT
# Optimizing hyperparemeters for asset num 86 remaining 15
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CBOE
# Optimizing hyperparemeters for asset num 87 remaining 14
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CBRE
# Optimizing hyperparemeters for asset num 88 remaining 13
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CDW
# Optimizing hyperparemeters for asset num 89 remaining 12
# Optimization result: [1, 2, 4]
# Optimizing hyperparameters for asset CE
# Optimizing hyperparemeters for asset num 90 remaining 11
# Optimization result: [1, 4]
# Optimizing hyperparameters for asset CNC
# Optimizing hyperparemeters for asset num 91 remaining 10
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset CNP
# Optimizing hyperparemeters for asset num 92 remaining 9
# Optimization result: [4, 5]
# Optimizing hyperparameters for asset CF
# Optimizing hyperparemeters for asset num 93 remaining 8
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CRL
# Optimizing hyperparemeters for asset num 94 remaining 7
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset SCHW
# Optimizing hyperparemeters for asset num 95 remaining 6
# Optimization result: [1, 5]
# Optimizing hyperparameters for asset CHTR
# Optimizing hyperparemeters for asset num 96 remaining 5
# Optimization result: [2, 4]
# Optimizing hyperparameters for asset CVX
# Optimizing hyperparemeters for asset num 97 remaining 4
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CMG
# Optimizing hyperparemeters for asset num 98 remaining 3
# Optimization result: [1, 2, 4, 5]
# Optimizing hyperparameters for asset CB
# Optimizing hyperparemeters for asset num 99 remaining 2
# Optimization result: [1, 4, 5]
# Optimizing hyperparameters for asset CHD
# Optimizing hyperparemeters for asset num 100 remaining 1
# Optimization result: [1, 2, 4, 5]
# Total clusters:
# ...
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AFL
# Optimizing hyperparemeters for asset num 12 remaining 89
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset A
# Optimizing hyperparemeters for asset num 13 remaining 88
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset APD
# Optimizing hyperparemeters for asset num 14 remaining 87
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset AKAM
# Optimizing hyperparemeters for asset num 15 remaining 86
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset ALK
# Optimizing hyperparemeters for asset num 16 remaining 85
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset ALB
# Optimizing hyperparemeters for asset num 17 remaining 84
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset ARE
# Optimizing hyperparemeters for asset num 18 remaining 83
# Optimization result: [1, 6]
# Optimizing hyperparameters for asset ALGN
# Optimizing hyperparemeters for asset num 19 remaining 82
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset ALLE
# Optimizing hyperparemeters for asset num 20 remaining 81
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset LNT
# Optimizing hyperparemeters for asset num 21 remaining 80
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset ALL
# Optimizing hyperparemeters for asset num 22 remaining 79
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset GOOGL
# Optimizing hyperparemeters for asset num 23 remaining 78
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset GOOG
# Optimizing hyperparemeters for asset num 24 remaining 77
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset MO
# Optimizing hyperparemeters for asset num 25 remaining 76
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AMZN
# Optimizing hyperparemeters for asset num 26 remaining 75
# Optimization result: [0, 1, 2, 4]
# Optimizing hyperparameters for asset AMCR
# Optimizing hyperparemeters for asset num 27 remaining 74
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset AEE
# Optimizing hyperparemeters for asset num 28 remaining 73
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AAL
# Optimizing hyperparemeters for asset num 29 remaining 72
# Optimization result: [0, 1, 2]
# Optimizing hyperparameters for asset AEP
# Optimizing hyperparemeters for asset num 30 remaining 71
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset AXP
# Optimizing hyperparemeters for asset num 31 remaining 70
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset AIG
# Optimizing hyperparemeters for asset num 32 remaining 69
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset AMT
# Optimizing hyperparemeters for asset num 33 remaining 68
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AWK
# Optimizing hyperparemeters for asset num 34 remaining 67
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AMP
# Optimizing hyperparemeters for asset num 35 remaining 66
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset ABC
# Optimizing hyperparemeters for asset num 36 remaining 65
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AME
# Optimizing hyperparemeters for asset num 37 remaining 64
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset AMGN
# Optimizing hyperparemeters for asset num 38 remaining 63
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset APH
# Optimizing hyperparemeters for asset num 39 remaining 62
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset ADI
# Optimizing hyperparemeters for asset num 40 remaining 61
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset ANSS
# Optimizing hyperparemeters for asset num 41 remaining 60
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset AON
# Optimizing hyperparemeters for asset num 42 remaining 59
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset APA
# Optimizing hyperparemeters for asset num 43 remaining 58
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset AAPL
# Optimizing hyperparemeters for asset num 44 remaining 57
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset AMAT
# Optimizing hyperparemeters for asset num 45 remaining 56
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset APTV
# Optimizing hyperparemeters for asset num 46 remaining 55
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset ANET
# Optimizing hyperparemeters for asset num 47 remaining 54
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset AJG
# Optimizing hyperparemeters for asset num 48 remaining 53
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset AIZ
# Optimizing hyperparemeters for asset num 49 remaining 52
# Optimization result: [1, 6]
# Optimizing hyperparameters for asset T
# Optimizing hyperparemeters for asset num 50 remaining 51
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset ATO
# Optimizing hyperparemeters for asset num 51 remaining 50
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset ADSK
# Optimizing hyperparemeters for asset num 52 remaining 49
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset ADP
# Optimizing hyperparemeters for asset num 53 remaining 48
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset AZO
# Optimizing hyperparemeters for asset num 54 remaining 47
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset AVB
# Optimizing hyperparemeters for asset num 55 remaining 46
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset AVY
# Optimizing hyperparemeters for asset num 56 remaining 45
# Optimization result: [1, 3]
# Optimizing hyperparameters for asset BKR
# Optimizing hyperparemeters for asset num 57 remaining 44
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset BAC
# Optimizing hyperparemeters for asset num 58 remaining 43
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BBWI
# Optimizing hyperparemeters for asset num 59 remaining 42
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset BAX
# Optimizing hyperparemeters for asset num 60 remaining 41
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset BDX
# Optimizing hyperparemeters for asset num 61 remaining 40
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset BBY
# Optimizing hyperparemeters for asset num 62 remaining 39
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset BIO
# Optimizing hyperparemeters for asset num 63 remaining 38
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset TECH
# Optimizing hyperparemeters for asset num 64 remaining 37
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BIIB
# Optimizing hyperparemeters for asset num 65 remaining 36
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BLK
# Optimizing hyperparemeters for asset num 66 remaining 35
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset BK
# Optimizing hyperparemeters for asset num 67 remaining 34
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BA
# Optimizing hyperparemeters for asset num 68 remaining 33
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BKNG
# Optimizing hyperparemeters for asset num 69 remaining 32
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BWA
# Optimizing hyperparemeters for asset num 70 remaining 31
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset BXP
# Optimizing hyperparemeters for asset num 71 remaining 30
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BSX
# Optimizing hyperparemeters for asset num 72 remaining 29
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset BMY
# Optimizing hyperparemeters for asset num 73 remaining 28
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset AVGO
# Optimizing hyperparemeters for asset num 74 remaining 27
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset BR
# Optimizing hyperparemeters for asset num 75 remaining 26
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset BRO
# Optimizing hyperparemeters for asset num 76 remaining 25
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CHRW
# Optimizing hyperparemeters for asset num 77 remaining 24
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CDNS
# Optimizing hyperparemeters for asset num 78 remaining 23
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CZR
# Optimizing hyperparemeters for asset num 79 remaining 22
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CPB
# Optimizing hyperparemeters for asset num 80 remaining 21
# Optimization result: [1, 2, 3]
# Optimizing hyperparameters for asset COF
# Optimizing hyperparemeters for asset num 81 remaining 20
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset CAH
# Optimizing hyperparemeters for asset num 82 remaining 19
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset KMX
# Optimizing hyperparemeters for asset num 83 remaining 18
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CCL
# Optimizing hyperparemeters for asset num 84 remaining 17
# Optimization result: [0, 1, 2]
# Optimizing hyperparameters for asset CTLT
# Optimizing hyperparemeters for asset num 85 remaining 16
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CAT
# Optimizing hyperparemeters for asset num 86 remaining 15
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CBOE
# Optimizing hyperparemeters for asset num 87 remaining 14
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset CBRE
# Optimizing hyperparemeters for asset num 88 remaining 13
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset CDW
# Optimizing hyperparemeters for asset num 89 remaining 12
# Optimization result: [1, 2, 5, 6]
# Optimizing hyperparameters for asset CE
# Optimizing hyperparemeters for asset num 90 remaining 11
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CNC
# Optimizing hyperparemeters for asset num 91 remaining 10
# Optimization result: [1, 2, 3, 6]
# Optimizing hyperparameters for asset CNP
# Optimizing hyperparemeters for asset num 92 remaining 9
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset CF
# Optimizing hyperparemeters for asset num 93 remaining 8
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CRL
# Optimizing hyperparemeters for asset num 94 remaining 7
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset SCHW
# Optimizing hyperparemeters for asset num 95 remaining 6
# Optimization result: [0, 1, 2, 6]
# Optimizing hyperparameters for asset CHTR
# Optimizing hyperparemeters for asset num 96 remaining 5
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CVX
# Optimizing hyperparemeters for asset num 97 remaining 4
# Optimization result: [1, 2, 4, 6]
# Optimizing hyperparameters for asset CMG
# Optimizing hyperparemeters for asset num 98 remaining 3
# Optimization result: [1, 2]
# Optimizing hyperparameters for asset CB
# Optimizing hyperparemeters for asset num 99 remaining 2
# Optimization result: [1, 2, 6]
# Optimizing hyperparameters for asset CHD
# Optimizing hyperparemeters for asset num 100 remaining 1
# Optimization result: [1, 2]
# Total clusters:
# Cluster 0, Risk factors: [1, 2, 3, 6],            Cluster Dimension: 18
# Assets in the cluster: ['MMM', 'ABBV', 'ADM', 'AES', 'LNT', 'MO', 'AEE', 'AMT', 'AWK', 'ABC', 'AME', 'APTV', 'T', 'ATO', 'BAX', 'BWA', 'CBRE', 'CNC']
# Cluster 1, Risk factors: [1, 2],            Cluster Dimension: 19
# Assets in the cluster: ['AOS', 'ACN', 'ATVI', 'AMD', 'A', 'AKAM', 'ALLE', 'ANSS', 'AON', 'AAPL', 'BIO', 'TECH', 'BR', 'CHRW', 'CDNS', 'CTLT', 'CHTR', 'CMG', 'CHD']
# Cluster 2, Risk factors: [1, 2, 3],            Cluster Dimension: 7
# Assets in the cluster: ['ABT', 'ALB', 'AEP', 'ADSK', 'AVB', 'BDX', 'CPB']
# Cluster 3, Risk factors: [1, 2, 6],            Cluster Dimension: 22
# Assets in the cluster: ['ADBE', 'APD', 'ALGN', 'ALL', 'AMCR', 'AMGN', 'ADI', 'AMAT', 'BKR', 'BBY', 'BLK', 'BMY', 'AVGO', 'BRO', 'CZR', 'CAH', 'KMX', 'CAT', 'CE', 'CF', 'CRL', 'CB']
# Cluster 4, Risk factors: [1, 2, 5, 6],            Cluster Dimension: 6
# Assets in the cluster: ['AAP', 'APH', 'AJG', 'AZO', 'BBWI', 'CDW']
# Cluster 5, Risk factors: [0, 1, 2, 6],            Cluster Dimension: 16
# Assets in the cluster: ['AFL', 'ALK', 'GOOGL', 'GOOG', 'AXP', 'AIG', 'AMP', 'BAC', 'BIIB', 'BK', 'BA', 'BKNG', 'BXP', 'BSX', 'COF', 'SCHW']
# Cluster 6, Risk factors: [1, 6],            Cluster Dimension: 2
# Assets in the cluster: ['ARE', 'AIZ']
# Cluster 7, Risk factors: [0, 1, 2, 4],            Cluster Dimension: 1
# Assets in the cluster: ['AMZN']
# Cluster 8, Risk factors: [0, 1, 2],            Cluster Dimension: 2
# Assets in the cluster: ['AAL', 'CCL']
# Cluster 9, Risk factors: [1, 2, 4, 6],            Cluster Dimension: 6
# Assets in the cluster: ['APA', 'ANET', 'ADP', 'CBOE', 'CNP', 'CVX']
# Cluster 10, Risk factors: [1, 3],            Cluster Dimension: 1
# Assets in the cluster: ['AVY']
#
# Useful clusters:
# Cluster 0, Risk factors: [1, 2, 3, 6]
# Assets in the cluster: ['MMM', 'ABBV', 'ADM', 'AES', 'LNT', 'MO', 'AEE', 'AMT', 'AWK', 'ABC', 'AME', 'APTV', 'T', 'ATO', 'BAX', 'BWA', 'CBRE', 'CNC']
# Cluster 1, Risk factors: [1, 2]
# Assets in the cluster: ['AOS', 'ACN', 'ATVI', 'AMD', 'A', 'AKAM', 'ALLE', 'ANSS', 'AON', 'AAPL', 'BIO', 'TECH', 'BR', 'CHRW', 'CDNS', 'CTLT', 'CHTR', 'CMG', 'CHD']
# Cluster 2, Risk factors: [1, 2, 3]
# Assets in the cluster: ['ABT', 'ALB', 'AEP', 'ADSK', 'AVB', 'BDX', 'CPB']
# Cluster 3, Risk factors: [1, 2, 6]
# Assets in the cluster: ['ADBE', 'APD', 'ALGN', 'ALL', 'AMCR', 'AMGN', 'ADI', 'AMAT', 'BKR', 'BBY', 'BLK', 'BMY', 'AVGO', 'BRO', 'CZR', 'CAH', 'KMX', 'CAT', 'CE', 'CF', 'CRL', 'CB']
# Cluster 4, Risk factors: [1, 2, 5, 6]
# Assets in the cluster: ['AAP', 'APH', 'AJG', 'AZO', 'BBWI', 'CDW']
# Cluster 5, Risk factors: [0, 1, 2, 6]
# Assets in the cluster: ['AFL', 'ALK', 'GOOGL', 'GOOG', 'AXP', 'AIG', 'AMP', 'BAC', 'BIIB', 'BK', 'BA', 'BKNG', 'BXP', 'BSX', 'COF', 'SCHW']
# Cluster 6, Risk factors: [1, 2, 4, 6]
# Assets in the cluster: ['APA', 'ANET', 'ADP', 'CBOE', 'CNP', 'CVX']
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -9.242675198342362e+16
#             Iterations: 6
#             Function evaluations: 96
#             Gradient evaluations: 5
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: -1444306886.2064133
#             Iterations: 9
#             Function evaluations: 103
#             Gradient evaluations: 5
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.09007699709374035
#             Iterations: 48
#             Function evaluations: 515
#             Gradient evaluations: 48
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -1.3752914270683728e+16
#             Iterations: 4
#             Function evaluations: 69
#             Gradient evaluations: 3
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.2528176515057525
#             Iterations: 15
#             Function evaluations: 118
#             Gradient evaluations: 13
# Inequality constraints incompatible    (Exit mode 4)
#             Current function value: -25534547.7757112
#             Iterations: 2
#             Function evaluations: 34
#             Gradient evaluations: 2
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.12417161407347035
#             Iterations: 41
#             Function evaluations: 359
#             Gradient evaluations: 41

# %%
portfolios
# Out:
# [[[['AAL', 'AJG', 'BWA', 'CPB', 'CHD'],
#    array([-7.01574537e-02, -8.26071795e-02,  1.04742637e-01,  7.58260625e-02,
#            9.78511140e-10])],
#   [['LNT', 'AEE', 'AEP', 'ATO', 'AVB', 'CNP'],
#    array([ 3.47753368e-05,  7.69854603e-02,  6.84866241e-03, -1.53348381e-01,
#            2.28614133e-08,  9.61160314e-02])],
#   [['ALK', 'AXP', 'AIG', 'BK', 'BXP', 'COF', 'CCL'],
#    array([-2.02586066e-08, -3.80045009e-09,  1.73278263e-01, -1.13619119e-01,
#            7.15684821e-09,  6.37987711e-03, -4.00560973e-02])]],
#  [[['AAL', 'ABC', 'BBWI', 'BK', 'BA', 'BMY', 'COF', 'CCL', 'CAT', 'SCHW'],
#    array([-4.81029242e-09, -3.96207221e-06, -1.09368975e-06,  3.36247080e-04,
#           -3.81123978e-04,  1.11718173e-01, -1.41765345e-01, -4.66634569e-04,
#            7.86038509e-02,  5.69200872e-05])]],
#  [[['AFL', 'ALK', 'AMCR', 'AXP', 'AIG', 'BKR', 'BAC', 'BA', 'BWA', 'COF'],
#    array([-1.80948560e-03, -2.97726694e-04,  3.57142210e-07, -7.99972234e-02,
#            1.47164647e-06, -6.94326427e-03, -2.99156903e-04, -8.95753243e-09,
#            1.44016667e-01, -9.99679719e-02])],
#   [['AOS', 'ABC', 'CHRW', 'CAH', 'CNP'],
#    array([-0.08422347, -0.00615765,  0.04301786,  0.15089042, -0.04904393])],
#   [['ADM', 'CAT', 'CF', 'SCHW'],
#    array([-0.07151827, -0.00022253,  0.1701885 , -0.09140403])]],
#  [[['AFL',
#     'ARE',
#     'ALGN',
#     'AMCR',
#     'AXP',
#     'AMT',
#     'AWK',
#     'ADP',
#     'BLK',
#     'COF',
#     'CTLT',
#     'CB'],
#    array([ 2.00538286e-08, -5.45843239e-02,  1.04722690e-01,  9.25301990e-03,
#            3.06393369e-02, -4.14070735e-04, -4.24953021e-04,  2.14732229e-04,
#           -3.17806045e-02,  6.02315249e-04, -7.92381198e-02,  2.14591873e-02])],
#   [['ADM',
#     'MO',
#     'AEE',
#     'AMP',
#     'ABC',
#     'AME',
#     'AJG',
#     'T',
#     'ATO',
#     'AVB',
#     'AVY',
#     'BKR',
#     'BAC',
#     'BK',
#     'BMY',
#     'CDNS',
#     'CPB',
#     'CBRE',
#     'CDW'],
#    array([-2.54849431e-02, -2.15021045e-02, -1.06524904e-02,  1.24806041e-02,
#            4.08187385e-02, -3.37221619e-02, -1.07682874e-02, -1.60880509e-02,
#           -6.74937953e-03,  1.95444278e-02, -1.24465511e-02,  1.94253245e-02,
#            5.71787615e-02, -2.54053538e-08,  1.64140220e-02, -1.00857894e-02,
#           -3.66783584e-03,  4.56740990e-03, -1.17364257e-02])],
#   [['ABT', 'ACN', 'BAX', 'BDX', 'BR', 'CHTR', 'CHD'],
#    array([-0.018359  , -0.08892618, -0.01552339, -0.02099065,  0.13366203,
#            0.02255598, -0.03331612])]],
#  [[['MMM', 'AMT', 'ABC', 'BAX', 'BMY', 'CHD'],
#    array([ 2.61500287e-03, -6.82716520e-02, -1.00476327e-01,  1.52928084e-01,
#            1.09414722e-07,  9.04215846e-03])],
#   [['ADBE', 'GOOGL', 'GOOG', 'ANSS', 'TECH'],
#    array([ 8.73268267e-02, -1.59045447e-01, -7.96657177e-07,  6.96060067e-02,
#            1.73542564e-02])],
#   [['AOS', 'ABT', 'ATO', 'AVY', 'BIO', 'BLK'],
#    array([-1.43261392e-01, -8.98105644e-03,  3.69147835e-02, -4.39708353e-05,
#           -1.89044682e-03,  1.42241683e-01])]],
#  [[['ALB', 'APH', 'BBY', 'CAT', 'CDW'],
#    array([-2.18611725e-02,  3.13771511e-07,  1.86102952e-01, -4.40468686e-02,
#           -8.13220268e-02])],
#   [['ADBE',
#     'AMD',
#     'A',
#     'AKAM',
#     'ANSS',
#     'AAPL',
#     'BIO',
#     'TECH',
#     'CDNS',
#     'CTLT',
#     'CRL'],
#    array([ 0.01148146, -0.0774284 ,  0.01915329, -0.00856321,  0.04326707,
#           -0.01653452,  0.00776094, -0.02395774,  0.05796852, -0.05021321,
#           -0.01700497])],
#   [['ABBV', 'APD', 'AON', 'BAX', 'BSX', 'CNC'],
#    array([-2.56884692e-02,  4.70622364e-02,  1.14503146e-01,  5.25709290e-08,
#           -1.45264709e-01,  8.14825520e-04])]],
#  [[['AOS', 'ABT', 'AAP', 'AMT', 'AMGN', 'BBY', 'CE'],
#    array([ 1.88803990e-03,  2.66423006e-02, -1.13091577e-03, -1.20214594e-01,
#            1.17650929e-01, -2.72247097e-07, -6.58062813e-02])],
#   [['ACN', 'A', 'GOOGL', 'MO', 'ABC', 'AAPL', 'T', 'ATO', 'AZO', 'AVB', 'CNC'],
#    array([-1.84317275e-02,  1.59806633e-02,  2.12239356e-02,  8.20194040e-03,
#            5.08355840e-02, -3.66470853e-03,  4.63137161e-02,  6.05000167e-03,
#           -1.17439387e-01, -4.51915093e-02, -1.59849410e-07])],
#   [['AMD', 'AES', 'ALGN', 'ADI', 'AIZ', 'BKR', 'CZR', 'CAH', 'CF'],
#    array([ 6.03617598e-03, -1.23081286e-04, -1.23823569e-04,  7.60714074e-02,
#            9.41384409e-03,  5.34455974e-02, -1.86500429e-01,  6.09184992e-04,
#           -1.00979008e-03])]],
#  [[['MMM',
#     'ABBV',
#     'AFL',
#     'ALK',
#     'AMCR',
#     'T',
#     'BKR',
#     'BBWI',
#     'BIIB',
#     'BK',
#     'BA',
#     'AVGO',
#     'KMX'],
#    array([ 3.27656082e-04, -2.34293570e-06, -2.18281900e-02,  2.18007639e-02,
#            4.19401807e-02,  7.53094067e-04,  3.61482466e-02,  8.79549060e-06,
#           -4.75532414e-02,  4.96549790e-02,  2.08345918e-02, -9.24479228e-02,
#           -3.33284621e-05])],
#   [['ACN', 'ALL', 'AAL', 'ADP', 'CPB', 'COF', 'CHD'],
#    array([-8.74814560e-03, -8.13061739e-04,  1.77085612e-01, -8.88765943e-03,
#           -4.30765915e-06, -1.22110640e-01, -1.56839068e-02])],
#   [['AEE', 'AMT', 'AWK', 'ABC', 'APA', 'CBOE', 'CNP', 'SCHW', 'CVX'],
#    array([-7.21968320e-03, -9.74384383e-02, -3.66610234e-02,  4.95033712e-04,
#           -7.98452777e-03, -1.08760273e-02,  1.72048481e-01,  6.09299511e-04,
#           -8.19361036e-07])]],
#  [],
#  [[['ADI', 'APA', 'ADSK', 'BKR', 'TECH', 'CMG'],
#    array([ 0.03185923, -0.00013585, -0.12683354, -0.01974848,  0.08004357,
#            0.07471267])],
#   [['ABT', 'AEE', 'AWK', 'AMGN', 'BDX', 'CPB'],
#    array([-0.01077232, -0.07456338,  0.01680915, -0.08168982,  0.105344  ,
#            0.04415467])]],
#  [[['ACN', 'A', 'AMT', 'AMAT', 'ADP', 'BAX', 'BDX', 'BR', 'CPB'],
#    array([-8.28033248e-03,  6.93890895e-02, -5.06857019e-02, -2.94385538e-09,
#           -4.57083095e-03,  4.64868044e-02,  5.20744807e-02, -1.01844434e-01,
#            1.65627190e-06])],
#   [['ALGN', 'ADI', 'AAPL', 'ADSK', 'BSX', 'AVGO', 'CZR', 'CRL', 'CMG'],
#    array([-4.22244453e-07,  2.25907449e-02,  8.53732020e-03, -2.45829891e-07,
#           -1.84930683e-03, -1.09689620e-01, -1.97142400e-02, -6.76481297e-04,
#            1.70274952e-01])],
#   [['ATVI', 'AKAM', 'BIO', 'BIIB'],
#    array([ 0.1417028 , -0.13873857,  0.0206341 , -0.03225786])]],
#  [[['AAP', 'APH', 'AJG', 'AZO', 'BBWI', 'CDW'],
#    array([ 1.37417416e-01, -2.63819983e-06,  3.56388320e-02, -4.13808754e-02,
#           -1.16376491e-01,  2.51708022e-03])],
#   [['APA', 'ANET', 'ADP', 'CBOE', 'CNP', 'CVX'],
#    array([ 1.12766431e-05, -7.96013870e-02,  1.08278998e-01, -7.88720601e-02,
#            2.98244028e-02, -3.67452085e-02])],
#   [['ABT', 'ALB', 'AEP', 'ADSK', 'AVB', 'BDX', 'CPB'],
#    array([ 6.90927708e-02,  8.82741552e-02, -5.11446427e-02, -1.15995067e-01,
#           -1.06671050e-03, -7.75870024e-03, -1.28640527e-06])]]]

# %%
 #Evaluate results
reduce_earning = 0.9
port_test_12fold = list()
for i in range (12):
    X_test = XD[ XD.index >= test_start_12fold[i]]
    X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
    # port_test = investment.InvestmnetWithEarningFilter(X_test_each_fold, target_portfolio, earnings_by_tickers, pre_period_by_ticker, post_period_by_ticker, 
    #                                                    initial_capital=1000, reduce_earning=reduce_earning)
    port_test = investment.Investment(X_test_each_fold, target_portfolio, initial_capital=1000)
    print('\nProposed strategy for ' + str(i + 1) + ' fold')
    port_test_12fold.append(port_test)
    evaluation.Strategy_Evaluation(port_test)
    print('\n')
# Out:
# Proposed strategy for 1 fold
# Percentage Profit: 0.547%
# Profit Factor: 1.857
# Percentage Drawdown: 0.19%
# Recovery Factor: 2.862
# Sharpe Ratio: 3.916
# Sortino Ratio: 6.115
#
#
#
# Proposed strategy for 2 fold
# Percentage Profit: -0.256%
# Profit Factor: 0.845
# Percentage Drawdown: 0.618%
# Recovery Factor: -0.413
# Sharpe Ratio: -0.933
# Sortino Ratio: -2.028
#
#
#
# Proposed strategy for 3 fold
# Percentage Profit: -1.671%
# Profit Factor: 0.482
# Percentage Drawdown: 2.479%
# Recovery Factor: -0.668
# Sharpe Ratio: -3.352
# Sortino Ratio: -3.16
#
#
#
# Proposed strategy for 4 fold
# Percentage Profit: -0.238%
# Profit Factor: 0.77
# Percentage Drawdown: 0.553%
# Recovery Factor: -0.43
# Sharpe Ratio: -1.403
# Sortino Ratio: -1.96
#
#
#
# Proposed strategy for 5 fold
# Percentage Profit: -0.151%
# Profit Factor: 0.81
# Percentage Drawdown: 0.393%
# Recovery Factor: -0.384
# Sharpe Ratio: -1.178
# Sortino Ratio: -1.443
#
#
#
# Proposed strategy for 6 fold
# Percentage Profit: -0.178%
# Profit Factor: 0.883
# Percentage Drawdown: 0.978%
# Recovery Factor: -0.182
# Sharpe Ratio: -0.781
# Sortino Ratio: -1.685
#
#
#
# Proposed strategy for 7 fold
# Percentage Profit: -1.532%
# Profit Factor: 0.23
# Percentage Drawdown: 1.801%
# Recovery Factor: -0.851
# Sharpe Ratio: -8.243
# Sortino Ratio: -18.738
#
#
#
# Proposed strategy for 8 fold
# Percentage Profit: 0.389%
# Profit Factor: 1.432
# Percentage Drawdown: 0.417%
# Recovery Factor: 0.927
# Sharpe Ratio: 2.118
# Sortino Ratio: 2.437
#
#
#
# Proposed strategy for 9 fold
# Percentage Profit: -2.109%
# Profit Factor: 0.401
# Percentage Drawdown: 3.083%
# Recovery Factor: -0.677
# Sharpe Ratio: -3.404
# Sortino Ratio: -2.602
#
#
#
# Proposed strategy for 10 fold
# Percentage Profit: 0.589%
# Profit Factor: 1.425
# Percentage Drawdown: 0.629%
# Recovery Factor: 0.935
# Sharpe Ratio: 2.296
# Sortino Ratio: 2.917
#
#
#
# Proposed strategy for 11 fold
# Percentage Profit: 0.482%
# Profit Factor: 1.94
# Percentage Drawdown: 0.145%
# Recovery Factor: 3.315
# Sharpe Ratio: 3.823
# Sortino Ratio: 6.948
#
#
#
# Proposed strategy for 12 fold
# Percentage Profit: -1.023%
# Profit Factor: 0.479
# Percentage Drawdown: 1.073%
# Recovery Factor: -0.953
# Sharpe Ratio: -4.349
# Sortino Ratio: -6.341

# %%
with open('./results/benchmark/nnpca_100_port_test_daily.txt', 'w') as file:
    for item in port_test_12fold:
        file.write(str(item)+"\n")
    file.close()

# %%
port_test
# Out:
# Date
# 2023-08-01    1000.000000
# 2023-08-02     998.807210
# 2023-08-03    1000.507272
# 2023-08-04     997.783584
# 2023-08-07     996.661803
# 2023-08-08     994.794263
# 2023-08-09     995.428973
# 2023-08-10     994.343699
# 2023-08-11     996.257694
# 2023-08-14     993.968105
# 2023-08-15     992.677443
# 2023-08-16     993.326465
# 2023-08-17     995.022025
# 2023-08-18     994.805199
# 2023-08-21     993.406179
# 2023-08-22     994.896633
# 2023-08-23     994.301098
# 2023-08-24     995.600637
# 2023-08-25     991.153024
# 2023-08-28     990.488118
# 2023-08-29     990.509695
# 2023-08-30     989.767859
# Name: Portfolio, dtype: float64

# %%
## Earnings calendars
earnings_by_tickers = {}
earnings_file_path = '../data/earnings_data.txt'
with open(earnings_file_path, 'r') as file:
    for line in file:
        ticker = line.split(':')[0]
        dates = line.split(':')[1].strip().split(',')
        earnings_by_tickers[ticker] = dates
        
optimized_earnings_file_path = './data/earnings_period.txt'
pre_period_by_ticker = {}
post_period_by_ticker = {}
with open(optimized_earnings_file_path, 'r') as fr:
    for line in fr:
        parts = line.split(',')
        ticker = parts[0]
        pre = float(parts[1])
        post = float(parts[2])
        pre_period_by_ticker[ticker] = pre
        post_period_by_ticker[ticker] = post

# %%
 #Evaluate results
for reduce in range(1, 20):
    reduce_earning = reduce / 10
    port_test_12fold = list()
    print('reduce earning: ', reduce_earning)
    for i in range (12):
        X_test = XD[ XD.index >= test_start_12fold[i]]
        X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
        port_test = investment.InvestmnetWithEarningFilter(X_test_each_fold, target_portfolio, earnings_by_tickers, pre_period_by_ticker, post_period_by_ticker, 
                                                        initial_capital=1000, reduce_earning=reduce_earning)
        # port_test = investment.Investment(X_test_each_fold, target_portfolio, initial_capital=1000)
        print('\nProposed strategy with filter for ' + str(i + 1) + ' fold')
        port_test_12fold.append(port_test)
        evaluation.Strategy_Evaluation(port_test)
        print('\n')

    with open(f'../results/earning_filter/benchmark_with_earning_filter_{reduce_earning}_100_port_test.txt', 'w') as file:
        for item in port_test_12fold:
            file.write(str(item)+"\n")
        file.close()
# Out:
# reduce earning:  0.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17864\2978492171.py in <module>
#       7        X_test = XD[ XD.index >= test_start_12fold[i]]
#       8        X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
# ----> 9        port_test = investment.InvestmnetWithEarningFilter(X_test_each_fold, target_portfolio, earnings_by_tickers, pre_period_by_ticker, post_period_by_ticker,
#      10                                                        initial_capital=1000, reduce_earning=reduce_earning)
#      11        # port_test = investment.Investment(X_test_each_fold, target_portfolio, initial_capital=1000)
#
# AttributeError: module 'C4I.investment' has no attribute 'InvestmnetWithEarningFilter'

# %%
#Evaluate benchmark
min_test_12fold = list()
for i in range (12):
    X_test = XD[ XD.index >= test_start_12fold[i]]
    X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
    X_each_fold = X[ X.index < test_start_12fold[i]]
    XD_each_fold = utils.DailyPrice2DailyReturn(X_each_fold)
    min_test = benchmarks.Minimal_Variance_Portfolio(XD_each_fold, X_test_each_fold)
    print('Minimal Variance Portfolio for ' + str(i + 1) + ' fold')
    evaluation.Strategy_Evaluation(min_test)
    min_test_12fold.append(min_test)
    evaluation.Strategy_Evaluation(min_test)
    print('\n')

# %%
file = open('./results/benchmark/min_100_test_model_and_statistics_last.txt','w')
for item in min_test_12fold:
    file.write(str(item)+"\n")
file.close()

# %%
mean_var_test_12fold = list()
for i in range (12):
    print('Start New')
    X_test = XD[ XD.index >= test_start_12fold[i]]
    X_test_each_fold = X_test[ X_test.index < test_start_12fold[i + 1]]
    X_each_fold = X[ X.index < test_start_12fold[i]]
    XD_each_fold = utils.DailyPrice2DailyReturn(X_each_fold)
    print('Start optimization')
    mean_var_test = benchmarks.Mean_Variance_Portfolio(XD_each_fold, X_test_each_fold)
    print('Mean-Variance Portfolio for ' + str(i + 1) + ' fold')
    mean_var_test_12fold.append(mean_var_test)
    print('\n')

# %%
file = open('./results/benchmark/mean_100_test_model_and_statistics_last.txt','w')
for item in mean_var_test_12fold:
    file.write(str(item)+"\n")
file.close()

# %%
proposed = pd.read_csv('./results/benchmark/benchmark_100_port_test.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in proposed[0]:
    if proposed[0][i] == "Name: Portfolio, dtype: float64" or proposed[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
proposed_deleted = pd.read_csv('proposed_model_and_statistics.txt', header = None, sep = '    ', skiprows = skip_rows)
proposed_deleted[0] = pd.to_datetime(proposed_deleted[0])
proposed_deleted.columns =['Date', 'Return_proposed']
proposed_deleted = proposed_deleted.set_index('Date')
proposed_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = proposed_deleted.loc[
         proposed_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    proposed_12_fold_read.append(temp)

# %%
mean = pd.read_csv('./results/benchmark/mean_100_test_model_and_statistics_last.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in mean[0]:
    if mean[0][i] == "Name: Mean-Variance, dtype: float64" or mean[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
mean_deleted = pd.read_csv('mean_var_test_model_and_statistics.txt', header = None, sep = '    ', skiprows = skip_rows)
mean_deleted[0] = pd.to_datetime(mean_deleted[0])
mean_deleted.columns =['Date', 'Return_mean']
mean_deleted = mean_deleted.set_index('Date')
mean_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = mean_deleted.loc[
         mean_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    mean_12_fold_read.append(temp)

# %%
min = pd.read_csv('./results/benchmark/min_100_test_model_and_statistics_last.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in min[0]:
    if min[0][i] == "Name: Minimal Variance, dtype: float64" or min[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
min_deleted = pd.read_csv('min_test_model_and_statistics.txt', header = None, sep = '    ', skiprows = skip_rows)
min_deleted[0] = pd.to_datetime(min_deleted[0])
min_deleted.columns =['Date', 'Return_min']
min_deleted = min_deleted.set_index('Date')
min_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = min_deleted.loc[
         min_deleted.index.month == month
    ]
    Series = temp.iloc[:,0]
    temp = pd.Series(Series, index = temp.index) 
    min_12_fold_read.append(temp)

# %%
#Plot the results
for i in range (12):
    proposed_12_fold_read[i].plot(figsize=(8,3))
    mean_12_fold_read[i].plot(figsize=(8,3))
    min_12_fold_read[i].plot(figsize=(8,3))
    plt.grid()
    plt.legend()
    plt.show()

# %%
for i in range (12):
    print("fold " + str(i + 1))
    print("\n Proposed method \n")
    evaluation.Strategy_Evaluation(proposed_12_fold_read[i])
    print("\n Mean Variance method \n")
    evaluation.Strategy_Evaluation(mean_12_fold_read[i])
    print("\n Min Variance method \n")
    evaluation.Strategy_Evaluation(min_12_fold_read[i])
    print("\n")
    print("\n")

# %% [markdown]
# Compare bench mark with earnings

# %%
 #Evaluate results
# all_proposed = []
# for reduce in range(1, 20):
#     reduce_earning = reduce / 10
#     port_test_12fold = list()

reduce_earning = 1.0
proposed = pd.read_csv(f'./results/earning_filter/benchmark_with_earning_filter_{reduce_earning}_100_port_test.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in proposed[0]:
    if proposed[0][i] == "Name: Portfolio, dtype: float64" or proposed[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
proposed_deleted = pd.read_csv('proposed_model_and_statistics.txt', header = None, sep = '    ', skiprows = skip_rows)
proposed_deleted[0] = pd.to_datetime(proposed_deleted[0])
proposed_deleted.columns =['Date', 'Return_proposed']
proposed_deleted = proposed_deleted.set_index('Date')
proposed_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = proposed_deleted.loc[
        proposed_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    proposed_12_fold_read.append(temp)
# all_proposed.append(proposed_12_fold_read)

# %%
print(all_proposed)

# %%
#Plot the results
for i in range (12):
    proposed_12_fold_read[i].plot(figsize=(8,3))
    mean_12_fold_read[i].plot(figsize=(8,3))
    min_12_fold_read[i].plot(figsize=(8,3))
    plt.grid()
    plt.legend()
    plt.show()

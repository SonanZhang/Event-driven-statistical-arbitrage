# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Benchmark

# %%
proposed = pd.read_csv('./results/benchmark/benchmark_100_port_test.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in proposed[0]:
    if proposed[0][i] == "Name: Portfolio, dtype: float64" or proposed[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
proposed_deleted = pd.read_csv('./results/benchmark/benchmark_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)
proposed_deleted[0] = pd.to_datetime(proposed_deleted[0])
proposed_deleted.columns =['Date', 'Return_proposed_benchmark']
proposed_deleted = proposed_deleted.set_index('Date')
benchmark_proposed_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = proposed_deleted.loc[
         proposed_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    benchmark_proposed_12_fold_read.append(temp)
# Out:
# /var/folders/75/sbcy5_zx3yxgz1xj55ggdxd80000gn/T/ipykernel_19263/1624881550.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   proposed_deleted = pd.read_csv('./results/benchmark/benchmark_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)

# %%
min = pd.read_csv('./results/benchmark/min_100_test_model_and_statistics_last.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in min[0]:
    if min[0][i] == "Name: Minimal Variance, dtype: float64" or min[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
min_deleted = pd.read_csv('./results/benchmark/min_100_test_model_and_statistics_last.txt', header = None, sep = '    ', skiprows = skip_rows)
min_deleted[0] = pd.to_datetime(min_deleted[0])
min_deleted.columns =['Date', 'Return_min']
min_deleted = min_deleted.set_index('Date')
min_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = min_deleted.loc[
         min_deleted.index.month == month
    ]
    Series = temp.iloc[:,0]
    temp = pd.Series(Series, index = temp.index) 
    min_12_fold_read.append(temp)
# Out:
# /var/folders/75/sbcy5_zx3yxgz1xj55ggdxd80000gn/T/ipykernel_19263/3769533804.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   min_deleted = pd.read_csv('./results/benchmark/min_100_test_model_and_statistics_last.txt', header = None, sep = '    ', skiprows = skip_rows)

# %%
mean = pd.read_csv('./results/benchmark/mean_100_test_model_and_statistics_last.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in mean[0]:
    if mean[0][i] == "Name: Mean-Variance, dtype: float64" or mean[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
mean_deleted = pd.read_csv('./results/benchmark/mean_100_test_model_and_statistics_last.txt', header = None, sep = '    ', skiprows = skip_rows)
mean_deleted[0] = pd.to_datetime(mean_deleted[0])
mean_deleted.columns =['Date', 'Return_mean']
mean_deleted = mean_deleted.set_index('Date')
mean_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = mean_deleted.loc[
         mean_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    mean_12_fold_read.append(temp)
# Out:
# /var/folders/75/sbcy5_zx3yxgz1xj55ggdxd80000gn/T/ipykernel_19263/3905347302.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   mean_deleted = pd.read_csv('./results/benchmark/mean_100_test_model_and_statistics_last.txt', header = None, sep = '    ', skiprows = skip_rows)

# %% [markdown]
# # Earning Filter

# %%
 #Evaluate results
# all_proposed = []
# for reduce in range(1, 20):
#     reduce_earning = reduce / 10
#     port_test_12fold = list()

reduce_earning = 0.8
proposed = pd.read_csv(f'./results/earning_filter/benchmark_with_earning_filter_{reduce_earning}_100_port_test.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in proposed[0]:
    if proposed[0][i] == "Name: Portfolio, dtype: float64" or proposed[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
proposed_deleted = pd.read_csv(f'./results/earning_filter/benchmark_with_earning_filter_{reduce_earning}_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)
proposed_deleted[0] = pd.to_datetime(proposed_deleted[0])
proposed_deleted.columns =['Date', 'Return_proposed_earnings']
proposed_deleted = proposed_deleted.set_index('Date')
earning_proposed_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = proposed_deleted.loc[
        proposed_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    earning_proposed_12_fold_read.append(temp)
# all_proposed.append(proposed_12_fold_read)
# Out:
# /var/folders/75/sbcy5_zx3yxgz1xj55ggdxd80000gn/T/ipykernel_19263/3684824733.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   proposed_deleted = pd.read_csv(f'./results/earning_filter/benchmark_with_earning_filter_{reduce_earning}_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)

# %% [markdown]
# # Quarterly

# %%
proposed = pd.read_csv('./results/quaterly/benchmark_100_port_test.txt', header = None, sep = '\t')
i = 0
skip_rows = list()
for item in proposed[0]:
    if proposed[0][i] == "Name: Portfolio, dtype: float64" or proposed[0][i] == "Date":
        skip_rows.append(i)
    i = i + 1
proposed_deleted = pd.read_csv('./results/quaterly/benchmark_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)
proposed_deleted[0] = pd.to_datetime(proposed_deleted[0])
proposed_deleted.columns =['Date', 'Return_proposed_quarterly']
proposed_deleted = proposed_deleted.set_index('Date')
quarterly_proposed_12_fold_read = list()
for i in range(12):
    month = i + 9
    if month > 12:
        month = month - 12
        
    temp = proposed_deleted.loc[
         proposed_deleted.index.month == month
    ]
    series = temp.iloc[:,0]
    temp = pd.Series(series, index = temp.index) 
    quarterly_proposed_12_fold_read.append(temp)
# Out:
# /var/folders/75/sbcy5_zx3yxgz1xj55ggdxd80000gn/T/ipykernel_19263/3889395370.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   proposed_deleted = pd.read_csv('./results/quaterly/benchmark_100_port_test.txt', header = None, sep = '    ', skiprows = skip_rows)

# %%
benchmark_proposed_12_fold_read[i] - quarterly_proposed_12_fold_read[i]
# Out:
# Date
# 2023-08-01     0.000000
# 2023-08-02    -2.066513
# 2023-08-03    -1.089488
# 2023-08-04    -1.925535
# 2023-08-07    -0.646682
# 2023-08-08    -3.033308
# 2023-08-09    -4.360689
# 2023-08-10    -1.138828
# 2023-08-11    -7.157508
# 2023-08-14    -7.371119
# 2023-08-15    -8.686157
# 2023-08-16    -8.410797
# 2023-08-17    -8.974843
# 2023-08-18    -8.309209
# 2023-08-21    -6.397923
# 2023-08-22   -13.016194
# 2023-08-23    -8.714206
# 2023-08-24   -14.641571
# 2023-08-25   -16.782399
# 2023-08-28   -16.049065
# 2023-08-29   -12.562893
# 2023-08-30   -13.159592
# dtype: float64

# %%
#Plot the results
for i in range (12):
    benchmark_proposed_12_fold_read[i].plot(figsize=(8,3))
    earning_proposed_12_fold_read[i].plot(figsize=(8,3))
    quarterly_proposed_12_fold_read[i].plot(figsize=(8,3))
    mean_12_fold_read[i].plot(figsize=(8,3))
    min_12_fold_read[i].plot(figsize=(8,3))
    plt.grid()
    plt.legend()
    plt.show()

# %%
from C4I import evaluation

for i in range (12):
    print("fold " + str(i + 1))
    print("\n Proposed benchmark method \n")
    evaluation.Strategy_Evaluation(benchmark_proposed_12_fold_read[i])
    print("\n Proposed Earnings method \n")
    evaluation.Strategy_Evaluation(earning_proposed_12_fold_read[i])
    print("\n Proposed quarterly method \n")
    evaluation.Strategy_Evaluation(quarterly_proposed_12_fold_read[i])
    print("\n Mean Variance method \n")
    evaluation.Strategy_Evaluation(mean_12_fold_read[i])
    print("\n Min Variance method \n")
    evaluation.Strategy_Evaluation(min_12_fold_read[i])
    print("\n")
    print("\n")
# Out:
# fold 1
#
#  Proposed benchmark method
#
# Percentage Profit: -1.083%
# Profit Factor: 0.624
# Percentage Drawdown: 2.024%
# Recovery Factor: -0.53
# Sharpe Ratio: -2.153
# Sortino Ratio: -1.842
#
#  Proposed Earnings method
#
# Percentage Profit: -0.877%
# Profit Factor: 0.664
# Percentage Drawdown: 1.82%
# Recovery Factor: -0.477
# Sharpe Ratio: -2.041
# Sortino Ratio: -1.911
#
#  Proposed quarterly method
#
# Percentage Profit: 0.653%
# Profit Factor: 1.57
# Percentage Drawdown: 0.374%
# Recovery Factor: 1.742
# Sharpe Ratio: 2.983
# Sortino Ratio: 5.637
#
#  Mean Variance method
#
# Percentage Profit: -2.051%
# Profit Factor: 0.27
# Percentage Drawdown: 2.364%
# Recovery Factor: -0.865
# Sharpe Ratio: -7.884
# Sortino Ratio: -15.914
#
#  Min Variance method
#
# Percentage Profit: 0.903%
# Profit Factor: 1.916
# Percentage Drawdown: 0.596%
# Recovery Factor: 1.516
# Sharpe Ratio: 3.259
# Sortino Ratio: 6.422
#
#
#
#
# fold 2
#
#  Proposed benchmark method
#
# Percentage Profit: 1.357%
# Profit Factor: 1.59
# Percentage Drawdown: 0.91%
# Recovery Factor: 1.478
# Sharpe Ratio: 2.957
# Sortino Ratio: 6.32
#
#  Proposed Earnings method
#
# Percentage Profit: 1.231%
# Profit Factor: 1.613
# Percentage Drawdown: 0.865%
# Recovery Factor: 1.413
# Sharpe Ratio: 2.986
# Sortino Ratio: 5.959
#
#  Proposed quarterly method
#
# Percentage Profit: -0.613%
# Profit Factor: 0.521
# Percentage Drawdown: 0.821%
# Recovery Factor: -0.746
# Sharpe Ratio: -4.066
# Sortino Ratio: -8.494
#
#  Mean Variance method
#
# Percentage Profit: -0.974%
# Profit Factor: 0.678
# Percentage Drawdown: 1.915%
# Recovery Factor: -0.506
# Sharpe Ratio: -2.246
# Sortino Ratio: -3.866
#
#  Min Variance method
#
# Percentage Profit: 0.841%
# Profit Factor: 1.697
# Percentage Drawdown: 0.78%
# Recovery Factor: 1.064
# Sharpe Ratio: 3.416
# Sortino Ratio: 4.379
#
#
#
#
# fold 3
#
#  Proposed benchmark method
#
# Percentage Profit: 1.392%
# Profit Factor: 1.412
# Percentage Drawdown: 1.415%
# Recovery Factor: 0.979
# Sharpe Ratio: 2.058
# Sortino Ratio: 2.665
#
#  Proposed Earnings method
#
# Percentage Profit: 1.054%
# Profit Factor: 1.368
# Percentage Drawdown: 1.252%
# Recovery Factor: 0.838
# Sharpe Ratio: 1.83
# Sortino Ratio: 2.231
#
#  Proposed quarterly method
#
# Percentage Profit: -0.785%
# Profit Factor: 0.652
# Percentage Drawdown: 1.235%
# Recovery Factor: -0.633
# Sharpe Ratio: -2.335
# Sortino Ratio: -3.084
#
#  Mean Variance method
#
# Percentage Profit: 0.964%
# Profit Factor: 1.618
# Percentage Drawdown: 0.652%
# Recovery Factor: 1.477
# Sharpe Ratio: 3.33
# Sortino Ratio: 5.435
#
#  Min Variance method
#
# Percentage Profit: -0.648%
# Profit Factor: 0.723
# Percentage Drawdown: 1.953%
# Recovery Factor: -0.332
# Sharpe Ratio: -1.803
# Sortino Ratio: -2.3
#
#
#
#
# fold 4
#
#  Proposed benchmark method
#
# Percentage Profit: -0.516%
# Profit Factor: 0.595
# Percentage Drawdown: 0.747%
# Recovery Factor: -0.691
# Sharpe Ratio: -3.067
# Sortino Ratio: -5.703
#
#  Proposed Earnings method
#
# Percentage Profit: -0.456%
# Profit Factor: 0.619
# Percentage Drawdown: 0.702%
# Recovery Factor: -0.649
# Sharpe Ratio: -2.908
# Sortino Ratio: -5.409
#
#  Proposed quarterly method
#
# Percentage Profit: 0.21%
# Profit Factor: 1.336
# Percentage Drawdown: 0.38%
# Recovery Factor: 0.551
# Sharpe Ratio: 1.799
# Sortino Ratio: 3.157
#
#  Mean Variance method
#
# Percentage Profit: -0.453%
# Profit Factor: 0.704
# Percentage Drawdown: 0.73%
# Recovery Factor: -0.619
# Sharpe Ratio: -1.855
# Sortino Ratio: -2.262
#
#  Min Variance method
#
# Percentage Profit: -0.539%
# Profit Factor: 0.707
# Percentage Drawdown: 1.046%
# Recovery Factor: -0.514
# Sharpe Ratio: -1.913
# Sortino Ratio: -2.861
#
#
#
#
# fold 5
#
#  Proposed benchmark method
#
# Percentage Profit: 0.273%
# Profit Factor: 1.217
# Percentage Drawdown: 0.918%
# Recovery Factor: 0.294
# Sharpe Ratio: 1.064
# Sortino Ratio: 2.38
#
#  Proposed Earnings method
#
# Percentage Profit: 0.429%
# Profit Factor: 1.408
# Percentage Drawdown: 0.745%
# Recovery Factor: 0.569
# Sharpe Ratio: 1.8
# Sortino Ratio: 4.525
#
#  Proposed quarterly method
#
# Percentage Profit: -0.482%
# Profit Factor: 0.551
# Percentage Drawdown: 0.685%
# Recovery Factor: -0.702
# Sharpe Ratio: -3.641
# Sortino Ratio: -6.875
#
#  Mean Variance method
#
# Percentage Profit: -1.087%
# Profit Factor: 0.573
# Percentage Drawdown: 1.087%
# Recovery Factor: -1.0
# Sharpe Ratio: -3.368
# Sortino Ratio: -6.111
#
#  Min Variance method
#
# Percentage Profit: -1.138%
# Profit Factor: 0.505
# Percentage Drawdown: 1.368%
# Recovery Factor: -0.832
# Sharpe Ratio: -4.139
# Sortino Ratio: -8.952
#
#
#
#
# fold 6
#
#  Proposed benchmark method
#
# Percentage Profit: -1.27%
# Profit Factor: 0.32
# Percentage Drawdown: 1.401%
# Recovery Factor: -0.905
# Sharpe Ratio: -6.571
# Sortino Ratio: -11.19
#
#  Proposed Earnings method
#
# Percentage Profit: -1.015%
# Profit Factor: 0.324
# Percentage Drawdown: 1.12%
# Recovery Factor: -0.905
# Sharpe Ratio: -6.526
# Sortino Ratio: -10.403
#
#  Proposed quarterly method
#
# Percentage Profit: 0.835%
# Profit Factor: 2.248
# Percentage Drawdown: 0.184%
# Recovery Factor: 4.521
# Sharpe Ratio: 5.467
# Sortino Ratio: 9.194
#
#  Mean Variance method
#
# Percentage Profit: 0.638%
# Profit Factor: 1.676
# Percentage Drawdown: 0.53%
# Recovery Factor: 1.204
# Sharpe Ratio: 3.051
# Sortino Ratio: 3.224
#
#  Min Variance method
#
# Percentage Profit: -1.66%
# Profit Factor: 0.241
# Percentage Drawdown: 1.66%
# Recovery Factor: -1.0
# Sharpe Ratio: -7.745
# Sortino Ratio: -14.425
#
#
#
#
# fold 7
#
#  Proposed benchmark method
#
# Percentage Profit: -0.362%
# Profit Factor: 0.796
# Percentage Drawdown: 1.253%
# Recovery Factor: -0.289
# Sharpe Ratio: -1.208
# Sortino Ratio: -1.602
#
#  Proposed Earnings method
#
# Percentage Profit: -0.457%
# Profit Factor: 0.738
# Percentage Drawdown: 1.26%
# Recovery Factor: -0.362
# Sharpe Ratio: -1.599
# Sortino Ratio: -2.03
#
#  Proposed quarterly method
#
# Percentage Profit: -0.142%
# Profit Factor: 0.904
# Percentage Drawdown: 0.88%
# Recovery Factor: -0.161
# Sharpe Ratio: -0.625
# Sortino Ratio: -0.964
#
#  Mean Variance method
#
# Percentage Profit: 0.87%
# Profit Factor: 1.809
# Percentage Drawdown: 0.435%
# Recovery Factor: 1.976
# Sharpe Ratio: 3.739
# Sortino Ratio: 10.37
#
#  Min Variance method
#
# Percentage Profit: 0.931%
# Profit Factor: 1.742
# Percentage Drawdown: 0.698%
# Recovery Factor: 1.33
# Sharpe Ratio: 3.672
# Sortino Ratio: 5.705
#
#
#
#
# fold 8
#
#  Proposed benchmark method
#
# Percentage Profit: -0.832%
# Profit Factor: 0.477
# Percentage Drawdown: 1.264%
# Recovery Factor: -0.656
# Sharpe Ratio: -4.06
# Sortino Ratio: -5.201
#
#  Proposed Earnings method
#
# Percentage Profit: -0.649%
# Profit Factor: 0.522
# Percentage Drawdown: 1.079%
# Recovery Factor: -0.6
# Sharpe Ratio: -3.548
# Sortino Ratio: -4.507
#
#  Proposed quarterly method
#
# Percentage Profit: -0.137%
# Profit Factor: 0.867
# Percentage Drawdown: 0.666%
# Recovery Factor: -0.204
# Sharpe Ratio: -0.847
# Sortino Ratio: -1.12
#
#  Mean Variance method
#
# Percentage Profit: 0.096%
# Profit Factor: 1.085
# Percentage Drawdown: 0.408%
# Recovery Factor: 0.235
# Sharpe Ratio: 0.554
# Sortino Ratio: 1.223
#
#  Min Variance method
#
# Percentage Profit: 1.052%
# Profit Factor: 2.288
# Percentage Drawdown: 0.311%
# Recovery Factor: 3.36
# Sharpe Ratio: 4.979
# Sortino Ratio: 9.892
#
#
#
#
# fold 9
#
#  Proposed benchmark method
#
# Percentage Profit: 0.313%
# Profit Factor: 1.176
# Percentage Drawdown: 0.973%
# Recovery Factor: 0.317
# Sharpe Ratio: 0.912
# Sortino Ratio: 1.151
#
#  Proposed Earnings method
#
# Percentage Profit: 0.25%
# Profit Factor: 1.161
# Percentage Drawdown: 0.775%
# Recovery Factor: 0.32
# Sharpe Ratio: 0.842
# Sortino Ratio: 1.122
#
#  Proposed quarterly method
#
# Percentage Profit: -1.169%
# Profit Factor: 0.463
# Percentage Drawdown: 1.711%
# Recovery Factor: -0.681
# Sharpe Ratio: -4.307
# Sortino Ratio: -6.212
#
#  Mean Variance method
#
# Percentage Profit: 0.67%
# Profit Factor: 1.363
# Percentage Drawdown: 1.059%
# Recovery Factor: 0.628
# Sharpe Ratio: 2.017
# Sortino Ratio: 2.88
#
#  Min Variance method
#
# Percentage Profit: -1.988%
# Profit Factor: 0.323
# Percentage Drawdown: 2.566%
# Recovery Factor: -0.77
# Sharpe Ratio: -6.767
# Sortino Ratio: -12.728
#
#
#
#
# fold 10
#
#  Proposed benchmark method
#
# Percentage Profit: 1.807%
# Profit Factor: 2.612
# Percentage Drawdown: 0.737%
# Recovery Factor: 2.416
# Sharpe Ratio: 6.18
# Sortino Ratio: 10.899
#
#  Proposed Earnings method
#
# Percentage Profit: 1.845%
# Profit Factor: 2.881
# Percentage Drawdown: 0.652%
# Recovery Factor: 2.786
# Sharpe Ratio: 6.724
# Sortino Ratio: 12.468
#
#  Proposed quarterly method
#
# Percentage Profit: 0.039%
# Profit Factor: 1.055
# Percentage Drawdown: 0.256%
# Recovery Factor: 0.153
# Sharpe Ratio: 0.341
# Sortino Ratio: 0.616
#
#  Mean Variance method
#
# Percentage Profit: 0.232%
# Profit Factor: 1.184
# Percentage Drawdown: 0.49%
# Recovery Factor: 0.473
# Sharpe Ratio: 1.145
# Sortino Ratio: 3.025
#
#  Min Variance method
#
# Percentage Profit: 1.046%
# Profit Factor: 2.036
# Percentage Drawdown: 0.326%
# Recovery Factor: 3.199
# Sharpe Ratio: 4.453
# Sortino Ratio: 8.069
#
#
#
#
# fold 11
#
#  Proposed benchmark method
#
# Percentage Profit: -0.075%
# Profit Factor: 0.955
# Percentage Drawdown: 1.232%
# Recovery Factor: -0.061
# Sharpe Ratio: -0.317
# Sortino Ratio: -0.66
#
#  Proposed Earnings method
#
# Percentage Profit: -0.191%
# Profit Factor: 0.873
# Percentage Drawdown: 1.19%
# Recovery Factor: -0.16
# Sharpe Ratio: -0.921
# Sortino Ratio: -2.071
#
#  Proposed quarterly method
#
# Percentage Profit: -0.065%
# Profit Factor: 0.925
# Percentage Drawdown: 0.504%
# Recovery Factor: -0.129
# Sharpe Ratio: -0.538
# Sortino Ratio: -1.042
#
#  Mean Variance method
#
# Percentage Profit: 0.283%
# Profit Factor: 1.214
# Percentage Drawdown: 0.584%
# Recovery Factor: 0.481
# Sharpe Ratio: 1.079
# Sortino Ratio: 1.507
#
#  Min Variance method
#
# Percentage Profit: 0.384%
# Profit Factor: 1.368
# Percentage Drawdown: 0.538%
# Recovery Factor: 0.715
# Sharpe Ratio: 1.79
# Sortino Ratio: 2.227
#
#
#
#
# fold 12
#
#  Proposed benchmark method
#
# Percentage Profit: -0.629%
# Profit Factor: 0.673
# Percentage Drawdown: 1.126%
# Recovery Factor: -0.558
# Sharpe Ratio: -2.161
# Sortino Ratio: -2.788
#
#  Proposed Earnings method
#
# Percentage Profit: -0.631%
# Profit Factor: 0.641
# Percentage Drawdown: 1.002%
# Recovery Factor: -0.63
# Sharpe Ratio: -2.507
# Sortino Ratio: -3.504
#
#  Proposed quarterly method
#
# Percentage Profit: 0.687%
# Profit Factor: 1.886
# Percentage Drawdown: 0.355%
# Recovery Factor: 1.925
# Sharpe Ratio: 4.215
# Sortino Ratio: 9.405
#
#  Mean Variance method
#
# Percentage Profit: 1.163%
# Profit Factor: 3.337
# Percentage Drawdown: 0.254%
# Recovery Factor: 4.535
# Sharpe Ratio: 8.027
# Sortino Ratio: 9.579
#
#  Min Variance method
#
# Percentage Profit: 2.19%
# Profit Factor: 6.556
# Percentage Drawdown: 0.357%
# Recovery Factor: 6.021
# Sharpe Ratio: 12.077
# Sortino Ratio: 18.012

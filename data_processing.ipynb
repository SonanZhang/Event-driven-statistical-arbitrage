# %% [markdown]
# ### Universe

# %%
import pandas as pd

# %%
universe_file_path = './data/snp500.csv'
df = pd.read_csv(universe_file_path, index_col=False)

# %%
df
# Out:
#     Symbol                 Name                  Sector
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4     ABMD              Abiomed             Health Care
# ..     ...                  ...                     ...
# 500    YUM          Yum! Brands  Consumer Discretionary
# 501   ZBRA   Zebra Technologies  Information Technology
# 502    ZBH        Zimmer Biomet             Health Care
# 503   ZION        Zions Bancorp              Financials
# 504    ZTS               Zoetis             Health Care
#
# [505 rows x 3 columns]

# %%
tickers = df['Symbol'].tolist()
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'AAP',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
# ...

# %% [markdown]
# ### Yahoo Historical data (2016-2023) and Earning Calendars

# %%
## Params
start_date = '2016-01-01'
end_date = '2023-08-31'

# %%
tickers =['MSFT', 'AAPL', 'MDB']

# %%
import yfinance as yf

open_result = pd.DataFrame()
close_result = pd.DataFrame()
high_result = pd.DataFrame()
low_result = pd.DataFrame()
volume_result = pd.DataFrame()
earnings_calendars = {}

for i in range(len(tickers)):
    ticker = tickers[i]
    #print(ticker, i, len(tickers))
    ticker_data = yf.Ticker(ticker)

    #historical data
    historical_data = ticker_data.history(start=start_date, end=end_date)
    #open = historical_data['Open']
    close = historical_data['Close']
    #high = historical_data['High']
    #low = historical_data['Low']
    #volume = historical_data['Volume']
    #open_result[ticker] = open
    close_result[ticker] = close
    #high_result[ticker] = high
    #low_result[ticker] = low
    #volume_result[ticker] = volume

# %%
close_result
# Out:
#                                   MMM        AOS         ABT        ABBV  \
# Date
# 2016-01-04 00:00:00-05:00  113.048523  33.202068   37.160885   41.186237
# 2016-01-05 00:00:00-05:00  113.541328  33.016586   37.152229   41.014664
# 2016-01-06 00:00:00-05:00  111.254501  32.362957   36.840607   41.021812
# 2016-01-07 00:00:00-05:00  108.544174  30.781895   35.957676   40.900269
# 2016-01-08 00:00:00-05:00  108.174561  29.686659   35.204590   39.785004
# ...                               ...        ...         ...         ...
# 2023-08-24 00:00:00-04:00   98.500000  68.800003  103.750000  146.630005
# 2023-08-25 00:00:00-04:00   98.949997  69.750000  104.209999  146.690002
# 2023-08-28 00:00:00-04:00  104.120003  70.709999  102.790001  147.429993
# 2023-08-29 00:00:00-04:00  105.570000  71.860001  103.870003  147.589996
# 2023-08-30 00:00:00-04:00  104.449997  72.300003  104.410004  148.320007
#
#                                 ABMD         ACN       ATVI        ADM  \
# Date
# ...

# %%
close_result.index = close_result.index.strftime("%Y-%m-%d")

# %%
close_result
# Out:
#                   MSFT        AAPL         MDB
# Date
# 2016-01-04   48.797729   24.009062         NaN
# 2016-01-05   49.020344   23.407412         NaN
# 2016-01-06   48.129871   22.949337         NaN
# 2016-01-07   46.455784   21.980774         NaN
# 2016-01-08   46.598263   22.097000         NaN
# ...                ...         ...         ...
# 2023-08-24  319.970001  176.380005  360.750000
# 2023-08-25  322.980011  178.610001  363.459991
# 2023-08-28  323.700012  180.190002  354.320007
# 2023-08-29  328.410004  184.119995  367.380005
# 2023-08-30  328.790009  187.649994  375.519989
#
# [1928 rows x 3 columns]

# %% [markdown]
# File to use in strategy

# %%
open_file_path = './data/open_price.csv'
close_file_path = './data/close_price.csv'
high_file_path = './data/high_price.csv'
low_file_path = './data/low_price.csv'
volume_file_path = './data/volume.csv'

# %%
close_result.to_csv(close_file_path)

# %%
msft = yf.Ticker('MSFT')
data = msft.get_earnings_dates(limit=60)
data.index
# Out:
# DatetimeIndex(['2024-07-23 06:00:00-04:00', '2024-04-23 06:00:00-04:00',
#                '2024-01-22 16:00:00-05:00', '2024-01-22 05:00:00-05:00',
#                '2023-10-23 06:00:00-04:00', '2023-07-25 12:00:00-04:00',
#                '2023-04-25 12:00:00-04:00', '2023-01-24 11:00:00-05:00',
#                '2022-10-25 12:00:00-04:00', '2022-07-26 12:00:00-04:00',
#                '2022-04-26 12:00:00-04:00', '2022-01-25 11:00:00-05:00',
#                '2021-10-26 12:00:00-04:00', '2021-07-27 12:00:00-04:00',
#                '2021-04-27 12:00:00-04:00', '2021-01-26 11:00:00-05:00',
#                '2020-10-27 12:00:00-04:00', '2020-07-22 12:00:00-04:00',
#                '2020-04-29 12:00:00-04:00', '2020-01-29 11:00:00-05:00',
#                '2019-10-23 12:00:00-04:00', '2019-07-18 12:00:00-04:00',
#                '2019-04-24 12:00:00-04:00', '2019-01-30 11:00:00-05:00',
#                '2018-10-24 12:00:00-04:00', '2018-07-19 12:00:00-04:00',
# ...

# %%
import yfinance as yf

earnigns_date_by_ticker = {}
for i in range(len(tickers)):
    print(i, len(tickers))
    ticker = tickers[i]
    ticker_data = yf.Ticker(ticker)
    earnings_data = ticker_data.get_earnings_dates(limit=60)
    if earnings_data is not None:
        earnigns_date_by_ticker[ticker] = earnings_data.index
# Out:
# 0 505
# 1 505
# 2 505
# 3 505
# 4 505
# 5 505
# 6 505
# 7 505
# 8 505
# 9 505
# 10 505
# 11 505
# 12 505
# 13 505
# 14 505
# 15 505
# 16 505
# 17 505
# 18 505
# 19 505
# 20 505
# 21 505
# 22 505
# 23 505
# 24 505
# 25 505
# 26 505
# 27 505
# 28 505
# 29 505
# 30 505
# 31 505
# 32 505
# 33 505
# 34 505
# 35 505
# 36 505
# 37 505
# 38 505
# 39 505
# 40 505
# 41 505
# 42 505
# 43 505
# 44 505
# 45 505
# 46 505
# 47 505
# 48 505
# 49 505
# 50 505
# 51 505
# 52 505
# 53 505
# 54 505
# 55 505
# 56 505
# 57 505
# 58 505
# 59 505
# 60 505
# 61 505
# 62 505
# 63 505
# 64 505
# - BRK.B: No earnings dates found, symbol may be delisted
# 65 505
# 66 505
# 67 505
# 68 505
# 69 505
# 70 505
# 71 505
# 72 505
# 73 505
# 74 505
# 75 505
# 76 505
# 77 505
# 78 505
# 79 505
# 80 505
# - BF.B: No earnings dates found, symbol may be delisted
# 81 505
# 82 505
# 83 505
# 84 505
# 85 505
# 86 505
# 87 505
# 88 505
# 89 505
# 90 505
# 91 505
# 92 505
# 93 505
# 94 505
# 95 505
# 96 505
# 97 505
# 98 505
# ...

# %%
for ticker in earnigns_date_by_ticker:
    print(ticker)
# Out:
# MMM
# AOS
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADM
# ADBE
# AAP
# AMD
# AES
# AFL
# A
# APD
# AKAM
# ALK
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# ANTM
# AON
# APA
# AAPL
# AMAT
# APTV
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# BKR
# BLL
# BAC
# BBWI
# BAX
# BDX
# BBY
# BIO
# TECH
# BIIB
# BLK
# BK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BRO
# CHRW
# CDNS
# CZR
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CTLT
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CDAY
# CERN
# CF
# CRL
# SCHW
# CHTR
# CVX
# CMG
# CB
# CHD
# CI
# CINF
# CTAS
# CSCO
# C
# CFG
# CTXS
# CLX
# CME
# CMS
# KO
# CTSH
# CL
# CMCSA
# CMA
# CAG
# COP
# ED
# STZ
# CPRT
# GLW
# CTVA
# COST
# CTRA
# CCI
# CSX
# CMI
# CVS
# DHI
# DHR
# DRI
# DVA
# DE
# DAL
# XRAY
# DVN
# DXCM
# FANG
# DLR
# DFS
# DISCA
# DISCK
# DISH
# DG
# DLTR
# D
# DPZ
# DOV
# DOW
# DTE
# DUK
# DRE
# DD
# DXC
# EMN
# ...

# %%
earnings_file_path = "./data/earnings_data.txt"
with open(earnings_file_path, "w") as fw:
    for ticker in earnigns_date_by_ticker:
        fw.write("%s:" % ticker)
        earnings_dates = earnigns_date_by_ticker[ticker].tolist()
        for i in range(len(earnings_dates)):
            if i == len(earnings_dates) - 1:
                fw.write("%s\n" % earnings_dates[i].strftime("%Y-%m-%d"))
            else:
                fw.write("%s," % earnings_dates[i].strftime("%Y-%m-%d"))
